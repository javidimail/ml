# %%
import pandas as pd

# %%
df = pd.read_csv('FL_insurance_sample.csv')

# %%
df
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 0        119736        FL      CLAY COUNTY       498960.0      498960.00
# 1        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 2        206893        FL      CLAY COUNTY       190724.4      190724.40
# 3        333743        FL      CLAY COUNTY            0.0       79520.76
# 4        172534        FL      CLAY COUNTY            0.0      254281.50
# 5        785275        FL      CLAY COUNTY            0.0      515035.62
# 6        995932        FL      CLAY COUNTY            0.0    19260000.00
# 7        223488        FL      CLAY COUNTY       328500.0      328500.00
# 8        433512        FL      CLAY COUNTY       315000.0      315000.00
# 9        142071        FL      CLAY COUNTY       705600.0      705600.00
# 10       253816        FL      CLAY COUNTY       831498.3      831498.30
# 11       894922        FL      CLAY COUNTY            0.0       24059.09
# ...

# %%
df['statecode']
# Out:
# 0        FL
# 1        FL
# 2        FL
# 3        FL
# 4        FL
# 5        FL
# 6        FL
# 7        FL
# 8        FL
# 9        FL
# 10       FL
# 11       FL
# 12       FL
# 13       FL
# 14       FL
# 15       FL
# 16       FL
# 17       FL
# 18       FL
# 19       FL
# 20       FL
# 21       FL
# 22       FL
# 23       FL
# 24       FL
# 25       FL
# 26       FL
# 27       FL
# 28       FL
# 29       FL
#          ..
# 36604    FL
# 36605    FL
# 36606    FL
# 36607    FL
# 36608    FL
# 36609    FL
# 36610    FL
# 36611    FL
# 36612    FL
# 36613    FL
# 36614    FL
# 36615    FL
# 36616    FL
# 36617    FL
# 36618    FL
# 36619    FL
# 36620    FL
# 36621    FL
# 36622    FL
# 36623    FL
# 36624    FL
# 36625    FL
# 36626    FL
# 36627    FL
# 36628    FL
# 36629    FL
# 36630    FL
# 36631    FL
# 36632    FL
# 36633    FL
# Name: statecode, dtype: object

# %%
df
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 0        119736        FL      CLAY COUNTY       498960.0      498960.00
# 1        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 2        206893        FL      CLAY COUNTY       190724.4      190724.40
# 3        333743        FL      CLAY COUNTY            0.0       79520.76
# 4        172534        FL      CLAY COUNTY            0.0      254281.50
# 5        785275        FL      CLAY COUNTY            0.0      515035.62
# 6        995932        FL      CLAY COUNTY            0.0    19260000.00
# 7        223488        FL      CLAY COUNTY       328500.0      328500.00
# 8        433512        FL      CLAY COUNTY       315000.0      315000.00
# 9        142071        FL      CLAY COUNTY       705600.0      705600.00
# 10       253816        FL      CLAY COUNTY       831498.3      831498.30
# 11       894922        FL      CLAY COUNTY            0.0       24059.09
# ...

# %%
df[['statecode','county']] # we pass a list for multiple columns!
# Out:
#       statecode           county
# 0            FL      CLAY COUNTY
# 1            FL      CLAY COUNTY
# 2            FL      CLAY COUNTY
# 3            FL      CLAY COUNTY
# 4            FL      CLAY COUNTY
# 5            FL      CLAY COUNTY
# 6            FL      CLAY COUNTY
# 7            FL      CLAY COUNTY
# 8            FL      CLAY COUNTY
# 9            FL      CLAY COUNTY
# 10           FL      CLAY COUNTY
# 11           FL      CLAY COUNTY
# 12           FL      CLAY COUNTY
# 13           FL      CLAY COUNTY
# 14           FL      CLAY COUNTY
# 15           FL      CLAY COUNTY
# 16           FL      CLAY COUNTY
# 17           FL      CLAY COUNTY
# 18           FL      CLAY COUNTY
# 19           FL      CLAY COUNTY
# 20           FL      CLAY COUNTY
# 21           FL      CLAY COUNTY
# 22           FL      CLAY COUNTY
# 23           FL      CLAY COUNTY
# 24           FL      CLAY COUNTY
# 25           FL      CLAY COUNTY
# 26           FL      CLAY COUNTY
# ...

# %%
df.describe()
# Out:
#             policyID  eq_site_limit  hu_site_limit  fl_site_limit  \
# count   36634.000000   3.663400e+04   3.663400e+04   3.663400e+04
# mean   548661.937189   7.314780e+05   2.074348e+06   6.646009e+05
# std    259912.926494   1.752300e+07   1.964150e+07   1.746114e+07
# min    100074.000000   0.000000e+00   0.000000e+00   0.000000e+00
# 25%    323647.750000   0.000000e+00   4.248106e+04   0.000000e+00
# 50%    548525.000000   0.000000e+00   1.926911e+05   0.000000e+00
# 75%    774252.000000   0.000000e+00   9.163381e+05   0.000000e+00
# max    999971.000000   2.160000e+09   2.160000e+09   2.160000e+09
#
#        fr_site_limit      tiv_2011      tiv_2012  eq_site_deductible  \
# count   3.663400e+04  3.663400e+04  3.663400e+04        3.663400e+04
# mean    9.911724e+05  2.172875e+06  2.571004e+06        7.787908e+02
# std     1.767178e+07  2.015015e+07  2.036777e+07        4.787979e+04
# min     0.000000e+00  9.000000e+01  7.337000e+01        0.000000e+00
# ...

# %%
myfilter = df[df['point_latitude'] > 30]

# %%
df[myfilter]
# Out:
#        policyID statecode             county  eq_site_limit  hu_site_limit  \
# 0        119736        FL        CLAY COUNTY       498960.0      498960.00
# 1        448094        FL        CLAY COUNTY      1322376.3     1322376.30
# 2        206893        FL        CLAY COUNTY       190724.4      190724.40
# 3        333743        FL        CLAY COUNTY            0.0       79520.76
# 4        172534        FL        CLAY COUNTY            0.0      254281.50
# 5        785275        FL        CLAY COUNTY            0.0      515035.62
# 6        995932        FL        CLAY COUNTY            0.0    19260000.00
# 7        223488        FL        CLAY COUNTY       328500.0      328500.00
# 8        433512        FL        CLAY COUNTY       315000.0      315000.00
# 9        142071        FL        CLAY COUNTY       705600.0      705600.00
# 10       253816        FL        CLAY COUNTY       831498.3      831498.30
# ...

# %%
df.as_matrix
# Out:
# <bound method DataFrame.as_matrix of        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 0        119736        FL      CLAY COUNTY       498960.0      498960.00
# 1        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 2        206893        FL      CLAY COUNTY       190724.4      190724.40
# 3        333743        FL      CLAY COUNTY            0.0       79520.76
# 4        172534        FL      CLAY COUNTY            0.0      254281.50
# 5        785275        FL      CLAY COUNTY            0.0      515035.62
# 6        995932        FL      CLAY COUNTY            0.0    19260000.00
# 7        223488        FL      CLAY COUNTY       328500.0      328500.00
# 8        433512        FL      CLAY COUNTY       315000.0      315000.00
# 9        142071        FL      CLAY COUNTY       705600.0      705600.00
# 10       253816        FL      CLAY COUNTY       831498.3      831498.30
# ...
