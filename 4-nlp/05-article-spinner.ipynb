# %%
import nltk
import random
import numpy as np

# %%
from bs4 import BeautifulSoup

# %%
positive_reviews = BeautifulSoup(open('datasets/positive.review').read())
# Out:
# /home/javidi/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/javidi/anaconda2/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
positive_reviews = positive_reviews.findAll('review_text')

# %%
trigrams = {}

# %%
for review in positive_reviews:
    s = review.text.lower()
    tokens = nltk.tokenize.word_tokenize(s)
    for i in xrange(len(tokens) - 2):
        k = (tokens[i], tokens[i+2])
        if k not in trigrams:
            trigrams[k]=[]
        trigrams[k].append(tokens[i+1])

# %% [raw]
# trigrams

# %%
trigrams
# Out:
# {(u'flaws', u'to'): [u'are'],
#  (u'and', u'drums'): [u'the'],
#  (u'pennies', u'what'): [u'.'],
#  (u'worth', u'hassle'): [u'the'],
#  (u'tends', u'pull'): [u'to'],
#  (u'small', u'you'): [u'issue'],
#  (u'fine', u"'ve"): [u'i'],
#  (u'but', u're-set'): [u'the'],
#  (u'image', u'voice'): [u'and'],
#  (u'i', u'running'): [u"'m", u'am', u"'m", u'was', u"'m"],
#  (u'$', u'than'): [u'more'],
#  (u'have', u'made'): [u'been', u'also'],
#  (u'camcorder', u'.'): [u'buff'],
#  (u'new', u'to'): [u'addiction'],
#  (u'use', u'battery'): [u'the', u'the'],
#  (u'by', u'including'): [u'.'],
#  (u'want', u'you'): [u'everytime', u'optical'],
#  (u'think', u'are'): [u'there', u'these'],
#  (u'sink', u'right'): [u'up'],
#  (u'picture', u'around'): [u'all'],
#  (u'connectors', u'for'): [u'.'],
#  (u'things', u'also'): [u'.'],
#  (u'was', u'sale'): [u'on'],
#  (u',', u'connecting'): [u'but'],
#  (u'has', u'uneven'): [u'an'],
#  (u'.', u'prefer'): [u'i', u'i'],
#  (u'display', u'to'): [u'fonts'],
#  (u'at', u'times'): [u'all', u'three', u'all', u'all'],
#  (u'force', u'printer'): [u'the'],
#  (u'in', u'pc'): [u'my'],
#  (u'always', u'all'): [u'run'],
#  (u'rubber', u'of'): [u'version'],
#  (u'one', u'case'): [u'place.the'],
#  (u'2', u'now'): [u'months'],
#  (u'cable', u'thin'): [u'is'],
#  (u'lens', u'on'): [u'hood'],
#  (u'to', u'bolt'): [u'the'],
#  (u'1khz', u'100'): [u','],
#  (u'99', u'.'): [u'too'],
#  (u'and', u'placement'): [u'battery'],
#  (u'to', u'accidentally'): [u'prevent'],
#  (u"'", u'their'): [u'on', u'down'],
#  (u'ique', u'outlook'): [u'uses'],
#  (u'disc', u'came'): [u'that'],
#  (u'am', u'recommending'): [u'highly'],
#  (u'inch', u'and'): [u'think'],
#  (u'played', u'on'): [u'fine', u'once'],
#  (u'cd', u'mp3'): [u'based'],
#  (u'skype', u'phones'): [u'wi-fi'],
#  (u'material', u'a'): [u','],
#  (u'now', u'that'): [u','],
#  (u'--', u'i'): [u'if', u'-'],
#  (u'.', u'very'): [u'its', u'also', u'provides', u'also', u'a'],
#  (u'it', u'seriously'): [u'was'],
#  (u'clear', u'or'): [u','],
#  (u'at', u'computer'): [u'a'],
#  (u'neighbors', u'complain'): [u'to'],
#  (u'by', u'mat'): [u'using'],
#  (u'shoulder', u'me'): [u'forced'],
#  (u'some', u'annoyances'): [u'minor'],
#  (u'most', u'my'): [u'of', u'of', u'of', u'of', u'of', u'of', u'of'],
#  (u'house', u'have'): [u','],
#  (u'a', u'connection'): [u'viable'],
#  (u'lot', u'charging'): [u'without', u'without'],
#  (u'better', u'using'): [u'when'],
#  (u'trick', u'me'): [u'gives'],
#  (u'need', u'it'): [u'for'],
#  (u'no', u'screen'): [u'a', u'lcd'],
#  (u'like', u'strong'): [u'its'],
#  (u'of', u'netgear'): [u'the'],
#  (u'in', u'tungsten'): [u'my'],
#  (u'here', u'how'): [u'is'],
#  (u'or', u'extra'): [u'need'],
#  (u'using', u'from'): [u'coordinates'],
#  (u'and', u'2nd'): [u'the'],
#  (u'much', u'space'): [u'counter'],
#  (u'ton', u'picture'): [u','],
#  (u'and', u'live'): [u'do'],
#  (u'terms', u'as'): [u'such'],
#  (u'be', u'until'): [u'tweaked'],
#  (u'to', u'disabled'): [u'be'],
#  (u'mostly', u'the'): [u'on'],
#  (u'cd-player', u'etc'): [u','],
#  (u')', u'superb'): [u'is'],
#  (u'jpgs', u'the'): [u'in'],
#  (u'a', u'mini'): [u'sony'],
#  (u'minor', u'-'): [u'complaints'],
#  (u'sensitivity', u'especially'): [u'-'],
#  (u'will', u'times'): [u'at'],
#  (u'players', u'and'): [u','],
#  (u'wired', u')'): [u'version'],
#  (u'...', u"'s"): [u'it', u'it'],
#  (u'the', u'everytime'): [u'hassle'],
#  (u'could', u'swap'): [u'never'],
#  (u'inch', u','): [u'samsungs'],
#  (u'anything', u'she'): [u'phone'],
#  (u'suggest', u'switch'): [u'you'],
#  (u'adjust', u'speed'): [u'your'],
#  (u'the', u'circuitry'): [u'sirf'],
#  (u'fabulous', u'--'): [u'product'],
#  (u'basslines', u'prominent'): [u'are'],
#  (u'this', u'site'): [u'web', u'web'],
#  (u'40', u'away'): [u'feet'],
#  (u'.', u'recomendation'): [u'my'],
#  (u',', u'making'): [u'and'],
#  (u'if', u'car'): [u'your'],
#  (u'flipping', u'the'): [u'through'],
#  (u'on', u'sources'): [u'outside'],
#  (u'should', u'use'): [u'*never*'],
#  (u'out', u'digital'): [u'the'],
#  (u'more', u'about'): [u'worried'],
#  (u'just', u'my'): [u'take', u'got', u'removed', u'recieved', u'got'],
#  (u'12', u'apple'): [u"''"],
#  (u'a', u'because'): [u'nightmare', u'desk'],
#  (u'clean', u'if'): [u'.'],
#  (u'freespace', u'on'): [u'available'],
#  (u'cases', u'flimsy'): [u'were'],
#  (u'kudos', u'fedex'): [u'to'],
#  (u'on', u'strength'): [u'the'],
#  (u'$', u'elsewhere'): [u'110'],
#  (u'a', u'years'): [u'few', u'few', u'few', u'few'],
#  (u'$', u'of'): [u'instead'],
#  (u'office', u'friday'): [u'on'],
#  (u'fadeout', u'i'): [u'.'],
#  (u'at', u'not'): [u'times'],
#  (u'increased', u'amount'): [u'the'],
#  (u'police', u','): [u'car'],
#  (u'not', u'emailed'): [u'get'],
#  (u'amazon', u"n't"): [u'could'],
#  (u'competitor', u'amazon.com'): [u'to'],
#  (u'sort', u'and'): [u'out'],
#  (u'source', u'which'): [u','],
#  (u'around', u'push'): [u'or'],
#  (u'are', u'few'): [u'a', u'a', u'a', u'a', u'a', u'very'],
#  (u'the', u'anymore'): [u'market'],
#  (u'wide', u'range'): [u'volume'],
#  (u',', u'interference'): [u'no'],
#  (u'of', u'street'): [u'the'],
#  (u'plastic', u'bose'): [u'.'],
#  (u'need', u'movies'): [u'.'],
#  (u'card', u'so'): [u'is'],
#  (u'gps', u'car'): [u'from'],
#  (u'rechargeables', u'to'): [u'ready'],
#  (u'away', u'several'): [u'for'],
#  (u'and', u'he'): [u'boy'],
#  (u'does', u'show'): [u"n't"],
#  (u'long', u'we'): [u'as'],
#  (u'dozen', u'and'): [u'discs'],
#  (u'pros', u'xlnt'): [u':'],
#  (u'netstumbler', u'pocketwarrior'): [u'or'],
#  (u'full', u'stars..it'): [u'5'],
#  (u'be', u'speakers'): [u'ideal'],
#  (u'receipt', u'e.g'): [u'.'],
#  (u'much', u'as'): [u'bass', u'useless', u'money'],
#  (u'-', u'design'): [u'simple', u'nice'],
#  (u'that', u'custom'): [u'the'],
#  (u'sound', u'although'): [u','],
#  (u'mimimum', u'of'): [u'anount'],
#  (u'electronics', u'typically'): [u'are', u'are'],
#  (u'uncomfortable', u'warm'): [u','],
#  (u'security', u'from'): [u'system'],
#  (u'slightly', u'and'): [u'brighter', u'smaller', u','],
#  (u'will', u'much'): [u'do'],
#  (u'destroyed', u'high'): [u'at'],
#  (u'can', u'connect'): [u'also'],
#  (u'ports', u'i'): [u','],
#  (u'white', u"'ve"): [u'would'],
#  (u'have', u'trying'): [u'been'],
#  (u'fast', u'pdf'): [u'for'],
#  (u'c530', u'lacks'): [u','],
#  (u'good', u'watching'): [u'for'],
#  (u'512', u'is'): [u'mb'],
#  (u'and', u'well'): [u'works', u'syncs', u'perform', u'go', u'works'],
#  (u'aging', u'mdr-v2'): [u'sony'],
#  (u';', u')'): [u'-', u'-', u'2', u'3'],
#  (u'short', u'3'): [u'memos'],
#  (u'impractical', u'some'): [u'in'],
#  (u'hoped', u'i'): [u'.'],
#  (u'nano', u'with'): [u'so'],
#  (u'adorable', u','): [u'pets'],
#  (u'provide-', u'for'): [u'especially'],
#  (u'power', u'/'): [u'!'],
#  (u'which', u'every'): [u'checks', u'covers'],
#  (u'product', u'why'): [u')'],
#  (u'horse', u'for'): [u'barn'],
#  (u'since', u'last'): [u'my'],
#  (u'your', u'directory'): [u'phone'],
#  (u'sides', u'this'): [u'and'],
#  (u'favorably', u'noticed'): [u')'],
#  (u'vacation', u'from'): [u'drive'],
#  (u'hell', u'.'): [u"''"],
#  (u'wherever', u'go'): [u'you'],
#  (u'.', u'cables'): [u'the', u'the'],
#  (u'like', u'dual'): [u'the'],
#  (u'out', u'which'): [u','],
#  (u'quibble', u'if'): [u'--'],
#  (u'window', u'covers'): [u'that'],
#  (u'anyone', u'does'): [u'who'],
#  (u'vx-6000', u'had'): [u'.'],
#  (u'performance', u'ease'): [u'and'],
#  (u'thin', u'flexible'): [u'and'],
#  (u'skins', u'which'): [u','],
#  (u'if', u'see'): [u'you'],
#  (u'loves', u'able'): [u'being', u'being'],
#  (u'brought', u'very'): [u'some'],
#  (u'best', u'i'): [u'mouse',
#   u'gadget-products',
#   u'earphones',
#   u'webcam',
#   u'product',
#   u'5.8',
#   u'.',
#   u'headphones',
#   u'mic',
#   u'.',
#   u'mouse',
#   u'purchase',
#   u'bag',
#   u'speakers',
#   u'device',
#   u'.',
#   u'.',
#   u'headphones',
#   u'buy',
#   u'accuracy',
#   u'phones',
#   u'mouse'],
#  (u'yet', u'a'): [u'burned'],
#  (u'button', u'go'): [u'presses'],
#  (u'both', u'leather'): [u'the'],
#  (u'the', u'wireless'): [u'old',
#   u'best',
#   u'microsoft',
#   u'logitech',
#   u'totally',
#   u'dual-band'],
#  (u'now', u'use'): [u'and', u'only'],
#  (u')', u'since'): [u'.'],
#  (u'that', u'call'): [u'i'],
#  (u'up', u'storing'): [u'for'],
#  (u'has', u'on'): [u'crashed', u'instructions'],
#  (u'checks', u'second'): [u'every'],
#  (u'problem', u'you'): [u'for', u'if'],
#  (u'rectangular', u'meant'): [u'box'],
#  (u"n't", u'why'): [u'know', u'know', u'get', u'understand', u'know'],
#  (u'package', u'found'): [u'and'],
#  (u'record', u'outgoing'): [u'of'],
#  (u'pocket', u'available'): [u'is'],
#  (u'with', u'full'): [u'the'],
#  (u'eq', u'works'): [u'that'],
#  (u'pc', u'in'): [u'was'],
#  (u'radio', u'keep'): [u'to'],
#  (u'it', u'into'): [u'slides', u'right'],
#  (u'anyway', u'a'): [u','],
#  (u'powered', u'of'): [u'kind'],
#  (u'was', u'really'): [u'a'],
#  (u'(', u'mannual'): [u'the'],
#  (u'the', u'horizontally'): [u'picture'],
#  (u'learn', u'to'): [u'how'],
#  (u'though', u'manual'): [u'the'],
#  (u'little', u'can'): [u'machine'],
#  (u'order', u'view'): [u'to'],
#  (u'11', u','): [u'outlets'],
#  (u'a', u'less'): [u'little', u'little', u'lot', u'little'],
#  (u'for', u'apartment'): [u'an'],
#  (u'i', u'glad'): [u"'m",
#   u"'m",
#   u"'m",
#   u'am',
#   u'am',
#   u"'m",
#   u'am',
#   u"'m",
#   u"'m",
#   u"'m"],
#  (u'end', u'-'): [u'result'],
#  (u'might', u'several'): [u'require'],
#  (u'on', u'satelites'): [u'6'],
#  (u'with', u'blessfully'): [u','],
#  (u'components', u'identical'): [u'are'],
#  (u'been', u'closely'): [u'looking'],
#  (u'back', u'have'): [u'and'],
#  (u'case', u'a'): [u'and', u'with', u'for', u'is'],
#  (u'and', u'start-up'): [u'windows'],
#  (u'lake', u','): [u'city'],
#  (u'not', u'how'): [u'know'],
#  (u'for', u'different'): [u'the', u'your'],
#  (u'disadvantage', u'an'): [u'of'],
#  (u'that', u'bright'): [u'are'],
#  (u'of', u'top'): [u'the', u'the', u'the'],
#  (u'printer', u'using'): [u'('],
#  (u'perfect', u'is'): [u'for'],
#  (u'made', u'the'): [u'into', u'before', u'into', u'off'],
#  (u'5', u"'s"): [u'stars..it', u'eb'],
#  (u'comes', u'watching'): [u'to'],
#  (u'meg', u'sticks'): [u'memory'],
#  (u'all', u'seem'): [u'they'],
#  (u'installation', u','): [u'cd'],
#  (u'my', u'if'): [u'route', u'chest'],
#  (u'attract', u'in'): [u'lint'],
#  (u'that', u'and'): [u'good', u'motor', u'holds', u'class', u'nite'],
#  (u'wear', u'buds'): [u'high-quality'],
#  (u'seems', u'a'): [u'like'],
#  (u'when', u'the'): [u'facing',
#   u'using',
#   u'hearing',
#   u'playing',
#   u'slung',
#   u'using',
#   u'using'],
#  (u'some', u'getting'): [u'time', u'time'],
#  (u'ton', u'headphones'): [u'of'],
#  (u'entry', u'you'): [u'that'],
#  (u'recommend', u'everyone'): [u'to'],
#  (u'channel', u'to'): [u'.'],
#  (u'wanted', u'unit'): [u'a'],
#  (u"'ve", u'gotten'): [u'both', u'never'],
#  (u're-booting', u'every'): [u'it'],
#  (u'however', u'connected'): [u'this'],
#  (u'design', u'to'): [u'easy'],
#  (u'select', u'for'): [u'manual'],
#  (u'itrip', u'the'): [u'.'],
#  (u'.', u'gets'): [u'it', u'it', u'this'],
#  (u'online', u'market'): [u'shopping'],
#  (u'premium', u'('): [u'price', u'device'],
#  (u'a', u'hand'): [u'bicycle'],
#  (u'groove', u'backpack'): [u'notebook'],
#  (u'large', u'printer'): [u'format', u'format'],
#  (u'the', u'tilt'): [u'mustang'],
#  (u'shop', u'for'): [u'around'],
#  (u'layer', u'drive'): [u'compatable'],
#  (u'want', u'i'): [u'when'],
#  (u'cities', u'this'): [u'.'],
#  (u'still', u'out'): [u'turned'],
#  (u'eye', u'so'): [u'.'],
#  (u'nice', u'and'): [u'bag', u'looking', u'feature', u'display'],
#  (u'hard', u','): [u'drive', u'rock', u'case', u'drive', u'surface'],
#  (u'.', u'headband'): [u'the'],
#  (u'n', u'bass'): [u"'"],
#  (u'first', u'this'): [u'purchased',
#   u'installed',
#   u'heard',
#   u',',
#   u'if',
#   u'.'],
#  (u'came', u'16mb'): [u'with'],
#  (u'especially', u'sharp'): [u'the'],
#  (u'small', u'glitch'): [u'technical'],
#  (u'wire', u'caught'): [u'getting'],
#  (u'the', u'all'): [u'bass',
#   u'viewer',
#   u'brightness',
#   u'charger',
#   u'headband'],
#  (u'(', u'is'): [u'which',
#   u'that',
#   u'that',
#   u'this',
#   u'48gx',
#   u'which',
#   u'which',
#   u'hd',
#   u'that',
#   u'this',
#   u'this',
#   u'there',
#   u'which',
#   u'which'],
#  (u'see', u'improvement'): [u'an'],
#  (u'a', u'larger'): [u'much', u'bit'],
#  (u'to', u'using'): [u'be', u'it', u'arrive', u'start'],
#  (u'but', u'remote'): [u'the'],
#  (u'bright', u')'): [u'blue', u'blue'],
#  (u'(', u'pointing'): [u'drivers'],
#  (u'mix', u'sabotaged'): [u'was'],
#  (u'have', u'mad'): [u'been'],
#  (u'button', u'great'): [u'works'],
#  (u'when', u'walk'): [u'i', u'you'],
#  (u'sceptical', u'reading'): [u'after'],
#  (u'would', u'that'): [u'say', u'be', u'be', u'think', u'guess'],
#  (u'wall-mounted', u'.'): [u'television'],
#  (u'part', u'and'): [u')'],
#  (u"'", u'my'): [u'with'],
#  (u'!', u'fabulous'): [u'colour'],
#  (u'speaker', u'on'): [u'docks'],
#  (u'has', u','): [u'this', u'component', u'dvi', u'radio', u'music', u'radio'],
#  (u'cloth', u'great'): [u','],
#  (u'limited', u'this'): [u'.'],
#  (u'me', u'look'): [u'to'],
#  (u'had', u'reversed'): [u'them'],
#  (u'individuals', u'consistent'): [u'remained'],
#  (u'cable/sat', u'filtering'): [u'cable'],
#  (u'speakers', u'their'): [u'.', u'for'],
#  (u'lcds', u'yet'): [u'in'],
#  (u'website', u'.'): [u')'],
#  (u'bought', u's'): [u'the'],
#  (u'hd-catv', u'('): [u'box'],
#  (u'price', u'does'): [u'tag'],
#  (u'readily', u'.'): [u'available'],
#  (u'and', u'tinny'): [u'``'],
#  (u'stereo', u','): [u'replacement', u'sound', u'system', u'system'],
#  (u'use', u'have'): [u'i'],
#  (u'excellent', u'and'): [u'buy',
#   u'construction',
#   u'sound',
#   u'bass',
#   u'price',
#   u'shape',
#   u'detail'],
#  (u'noise', u'but'): [u'reduction', u','],
#  (u'of', u"'s"): [u'cd',
#   u'it',
#   u'brian',
#   u'd-link',
#   u'day',
#   u'it',
#   u'it',
#   u'vivaldi',
#   u'today',
#   u'it',
#   u'kodak',
#   u'canon',
#   u'it',
#   u'it',
#   u'it',
#   u'it',
#   u'cd-r'],
#  (u'pda', u'does'): [u'that'],
#  (u'luck', u'right'): [u'started'],
#  (u'being', u'now'): [u'used'],
#  (u'paper', u'epson'): [u'-'],
#  (u'them', u'turn'): [u'was'],
#  (u'configuration', u'and'): [u','],
#  (u"n't", u'will'): [u'you'],
#  (u'grip', u'.'): [u'on'],
#  (u'for', u'service'): [u'great'],
#  (u'setup', u'that'): [u'now'],
#  (u'had', u'no'): [u'absolutely'],
#  (u'to', u'left'): [u'your', u'lean', u'my'],
#  (u'comfortable', u'type'): [u'to'],
#  (u'was', u'replaced'): [u'promptly'],
#  (u'open', u'then'): [u'and'],
#  (u'a', u'shady'): [u'bit'],
#  (u'sticks', u'a'): [u'are'],
#  (u')', u'requires'): [u'which'],
#  (u'and', u'things'): [u'the'],
#  (u'connection', u'i'): [u',', u'but', u'.', u'so'],
#  (u'of', u'cost'): [u'the'],
#  (u'so', u"'ve"): [u'you', u'i'],
#  (u'must', u'webcams'): [u'for'],
#  (u'my', u'1280'): [u'epson'],
#  (u'high', u'headphones'): [u'quality'],
#  (u'this', u'``'): [u'unit'],
#  (u'yet', u'read'): [u'to'],
#  (u'installation', u'simple'): [u'was', u'is'],
#  (u'need', u'hold'): [u'to'],
#  (u'positive', u'.'): [u'reviews', u'rating'],
#  (u'searched', u'dvd'): [u'for'],
#  (u'hardcase', u'extra'): [u','],
#  (u'quality', u'obvious'): [u'is'],
#  (u'neither', u'alarm'): [u'an'],
#  (u'devices', u'five'): [u'over'],
#  (u'can', u'had'): [u'be', u'be'],
#  (u'wow', u'cod2'): [u'and'],
#  (u'one', u'had'): [u'had'],
#  (u'comes', u'both'): [u'with'],
#  (u'have', u'watts'): [u'more'],
#  (u'the', u'en-7100'): [u'envision'],
#  (u'and', u'custom'): [u'the'],
#  (u'by', u'unit'): [u'the'],
#  (u'manufacturer', u'steve'): [u'.'],
#  (u',', u'n'): [u'drum'],
#  (u'have', u'directv'): [u'a'],
#  (u'trustworthy', u'applied'): [u'when'],
#  (u'compatible', u'too'): [u','],
#  (u'floor', u'wall'): [u'and'],
#  (u'stamp', u'the'): [u'on'],
#  (u'go', u'out'): [u'all'],
#  (u'to', u'window'): [u'the'],
#  (u'(', u'drive'): [u'i'],
#  (u'cause', u'friend'): [u'my'],
#  (u'is', u'their'): [u'that'],
#  (u'right', u'if'): [u'.'],
#  (u'item', u'cnet'): [u'on'],
#  (u'color', u'-'): [u'screen'],
#  (u"n't", u'fax'): [u'use'],
#  (u'player', u'more'): [u'function'],
#  (u'knows', u'dead'): [u'is'],
#  (u'range', u'better'): [u'is'],
#  (u'an', u'combination'): [u'unbeatable'],
#  (u',', u'dragged'): [u'i'],
#  (u'your', u'greeting'): [u'own'],
#  (u'users', u'still'): [u'.'],
#  (u',', u'connect'): [u'and', u'just'],
#  (u'bridge', u'start'): [u'i'],
#  (u'hotspots', u'the'): [u'around'],
#  (u'amplifier', u'two'): [u'are'],
#  (u'mind', u'the'): [u'that'],
#  (u'rock', u')'): [u'band'],
#  (u'of', u'photo'): [u'most'],
#  (u'held', u'very'): [u'together'],
#  (u'find', u'preferred'): [u'i'],
#  (u'.', u'verbatim'): [u'these', u'the'],
#  (u'the', u'headphones'): [u'best', u'h250', u'best'],
#  (u'ipod', u'music'): [u'old'],
#  (u'with', u'ique'): [u'the'],
#  (u'nemerous', u'have'): [u'people'],
#  (u'of', u'pinna'): [u'the'],
#  (u'backpack', u'this'): [u','],
#  (u'thx', u'!'): [u'certified'],
#  (u'ever', u'to'): [u'have', u'need'],
#  (u'misplacing', u'tv'): [u'the'],
#  (u'to', u'this'): [u'(',
#   u'suspect',
#   u'rate',
#   u'get',
#   u'purchase',
#   u'configure',
#   u'review',
#   u'keep',
#   u'ship',
#   u'purchase',
#   u'buy',
#   u'use',
#   u'get',
#   u'understand',
#   u'find',
#   u'try',
#   u'correct',
#   u'repeat',
#   u'hide',
#   u'use',
#   u'using',
#   u'run',
#   u'spend',
#   u'whether',
#   u'plug',
#   u'like',
#   u'purchase',
#   u'keep',
#   u'use',
#   u'use',
#   u'buy',
#   u'use',
#   u'explore',
#   u'try',
#   u'say',
#   u'buy',
#   u'get',
#   u'use',
#   u'prevent',
#   u'buy',
#   u'purchase',
#   u'defend',
#   u'have',
#   u'use',
#   u'avoid',
#   u'wear',
#   u'get',
#   u'press'],
#  (u'plastic', u'soft'): [u'and'],
#  (u'similar', u'.'): [u'alternatives', u'type'],
#  (u'have', u'say'): [u'to', u'to', u'to'],
#  (u'stood', u'the'): [u'on'],
#  (u'said', u'i'): [u',', u'but', u',', u','],
#  (u'ca', u'find'): [u"n't", u"n't", u"n't", u"n't"],
#  (u'where', u'am'): [u'i'],
#  (u'the', u'watergate'): [u'``'],
#  (u'then', u'know'): [u'i'],
#  (u'and', u'nothing'): [u'have'],
#  (u'otherwise', u'internal'): [u'the'],
#  (u'plus', u'but'): [u','],
#  (u'--', u'manufacturer'): [u'the'],
#  (u'five', u'is'): [u'days'],
#  (u'.', u'office'): [u'my'],
#  (u'people', u'tried'): [u'who'],
#  (u'back', u'or'): [u'yard'],
#  (u'all', u'different'): [u'the', u'the'],
#  (u'the', u'point'): [u'selling', u'price', u'widest', u'thickest'],
#  (u'fumble', u'you'): [u'for'],
#  (u'5.', u'is'): [u'there'],
#  (u'simpson', u'beer'): [u'slurps'],
#  (u')', u'the'): [u'.',
#   u'stretch',
#   u'.',
#   u'at',
#   u'from',
#   u',',
#   u',',
#   u'press',
#   u'.',
#   u'and',
#   u'for',
#   u'.',
#   u'that',
#   u'.',
#   u'on',
#   u'.',
#   u'.',
#   u'and',
#   u'.',
#   u'!',
#   u'reads',
#   u'for',
#   u'.',
#   u'.',
#   u'.',
#   u'.',
#   u'for',
#   u'and',
#   u'and',
#   u'but',
#   u',',
#   u'for',
#   u'.',
#   u'whereas',
#   u'.',
#   u'and',
#   u'on',
#   u'.',
#   u'.',
#   u'because',
#   u'and',
#   u'.',
#   u',',
#   u'.',
#   u'.',
#   u'and',
#   u'and',
#   u'.',
#   u'when',
#   u'.',
#   u'.'],
#  (u'turn', u'off'): [u'it'],
#  (u'port', u'still'): [u'('],
#  (u'made', u'aware'): [u'me'],
#  (u'works', u'of'): [u'most'],
#  (u'ever', u'needed'): [u'be'],
#  (u'contrast', u'set'): [u'was'],
#  (u'take', u'me'): [u'with'],
#  (u'bose', u'if'): [u'.'],
#  (u'scratching', u'scuffing'): [u','],
#  (u'farther', u'than'): [u'down'],
#  (u'players', u'out'): [u'are'],
#  (u'minimum', u'should'): [u'there'],
#  (u'1', u':'): [u'vrms'],
#  (u'bit', u'+music'): [u'thick'],
#  (u'internet', u'a'): [u'and'],
#  (u'tho', u'they'): [u'.'],
#  (u'so', u'decided'): [u'i', u'i'],
#  (u'of', u'wear'): [u'hard'],
#  (u'bought', u'hd-600'): [u'the'],
#  (u'does', u'support'): [u"n't", u"n't", u'not', u"n't"],
#  (u'is', u'warmer'): [u'simply'],
#  (u'excellecnt', u'space'): [u'storage'],
#  (u'in', u'wall'): [u'a', u'the', u'a', u'the'],
#  (u'with', u'flourescent'): [u'compact'],
#  (u'bought', u'battery'): [u'this'],
#  (u'in', u'field'): [u'each', u'every'],
#  (u'worked', u'advertised'): [u'as'],
#  (u'used', u'on'): [u'it', u'it', u'this', u'it', u'it', u'this'],
#  (u'the', u'great'): [u'same'],
#  (u'may', u'know'): [u'already'],
#  (u'diaphragm', u'to'): [u')'],
#  (u'old', u'receiver'): [u'sony'],
#  (u'and', u'perfect'): [u'a'],
#  (u'navigation', u'both'): [u'tool'],
#  (u'microphone', u'had'): [u'i'],
#  (u'is', u'gone'): [u'nearly'],
#  (u'had', u'try'): [u'to'],
#  (u'2', u'ago'): [u'years', u'years'],
#  (u'co-channel', u'adjacent'): [u'and'],
#  (u'you', u'new'): [u"'re"],
#  (u'go', u'sleep'): [u'to'],
#  (u'av-sim', u'is'): [u'controls'],
#  (u'of', u'anti'): [u'an'],
#  (u'have', u'purchased'): [u"n't"],
#  (u'to', u'is'): [u'do',
#   u'do',
#   u'this',
#   u'do',
#   u'another',
#   u'pc',
#   u'cds',
#   u'them',
#   u'do',
#   u'recover',
#   u'note',
#   u'know',
#   u'do',
#   u'purchase',
#   u'me',
#   u'do',
#   u'and',
#   u'obtain'],
#  (u'a', u'side'): [u'nice'],
#  (u'compatible', u'motorola'): [u'with'],
#  (u'on', u'bed'): [u'your'],
#  (u'does', u'include'): [u'not', u'not', u'not'],
#  (u"n't", u'13x19'): [u'make'],
#  (u'it', u'supposed'): [u'was', u"'s", u"'s", u'is'],
#  (u'opt', u'verbatim'): [u'for'],
#  (u'everything', u'immediately'): [u'updated'],
#  (u'it', u'indescribable'): [u"'s"],
#  (u'operational', u'of'): [u'problem'],
#  (u'holder', u'it'): [u'.'],
#  (u'.', u'picturemate'): [u'the'],
#  (u'head', u'the'): [u'with', u'to', u'.'],
#  (u'?', u'answer'): [u'the'],
#  (u"''", u'no'): [u'for'],
#  (u'mcintosh', u'('): [u'system'],
#  (u',', u'holding'): [u'while'],
#  (u'w/o', u'!'): [u'it'],
#  (u'really', u'by'): [u'impressed'],
#  (u'or', u'connectability'): [u'ps2'],
#  (u'will', u'into'): [u'fit'],
#  (u'pro', u'paper'): [u"''", u"''"],
#  (u'we', u'very'): [u'are', u'are', u'are'],
#  (u',', u'stood'): [u'i'],
#  (u'tacky', u'one'): [u'.'],
#  (u'them', u'there'): [u'.', u'because', u'if', u'that', u'on'],
#  (u'i', u'into'): [u'plug', u'ran'],
#  (u'least', u'days'): [u'2'],
#  (u'plastic', u'on'): [u'coverings'],
#  (u'home', u'weeks'): [u'three'],
#  (u'their', u'are'): [u'highs', u'bugs', u'profits'],
#  (u',', u'addition'): [u'in'],
#  (u'to', u'two'): [u'put', u'reveal', u'hit'],
#  (u'light', u'load'): [u'document'],
#  (u'ca', u'rate'): [u"n't"],
#  (u'bug', u'the'): [u'where'],
#  (u'they', u're-recordable'): [u'are'],
#  (u'image', u'software'): [u'editing'],
#  (u'cd', u'which'): [u"'s"],
#  (u'submission', u'this'): [u'of'],
#  (u'info', u'.'): [u'only'],
#  (u'anyone', u"'s"): [u'who'],
#  (u'my', u'fm'): [u'second'],
#  (u'our', u'room'): [u'living'],
#  (u'dvd', u'may'): [u'players'],
#  (u'a', u'pad'): [u'basic', u'mouse'],
#  (u'greeting', u'will'): [u'which'],
#  (u'throughout', u'n.e.w'): [u','],
#  (u'radio', u'can'): [u'...'],
#  (u'criteria', u'but'): [u','],
#  (u'i', u'assign'): [u'could'],
#  (u'like', u'at'): [u'being', u'them', u'looking'],
#  (u'vegas', u','): [u'vacation'],
#  (u'aspects', u'are'): [u'that'],
#  (u'longer', u'eagle'): [u'.'],
#  (u'uses', u'same'): [u'the'],
#  (u'--', u'was'): [u'it', u'this'],
#  (u'go', u'seconds'): [u'within'],
#  (u'bose', u'harman'): [u',', u'and'],
#  (u'keyboard', u'my'): [u'on', u'.'],
#  (u'implant', u'a'): [u'is'],
#  (u'c340', u'screen'): [u'map'],
#  (u"'s", u'free'): [u'distortion'],
#  (u'tuner', u'it'): [u'.'],
#  (u'heating', u'my'): [u'up'],
#  (u'impressed', u'for'): [u'.'],
#  (u'would-be', u'pilferers'): [u'pc'],
#  (u'off', u'mp3'): [u'the'],
#  (u'to', u'better'): [u'go', u'a', u'be'],
#  (u'on', u'annual'): [u'an'],
#  (u'have', u'every'): [u'tried', u'used'],
#  (u'state', u'they'): [u'that'],
#  (u'voice', u'are'): [u'directions'],
#  (u'name', u'knew'): [u'i'],
#  (u'details', u'i'): [u'that'],
#  (u'that', u'profesional'): [u'to'],
#  (u'as', u'people'): [u'many', u'some'],
#  (u'a', u'nano'): [u'1g'],
#  (u'or', u'programming'): [u'hd'],
#  (u'it', u'satisfy'): [u'will'],
#  (u'backing', u'my'): [u'up'],
#  (u'only', u'``'): [u'the'],
#  (u'all', u'evening'): [u'last'],
#  (u'rear', u'input'): [u'component'],
#  (u'the', u'weight'): [u'light', u'same'],
#  (u'protector', u'my'): [u'for'],
#  (u'while', u'price'): [u'the'],
#  (u'you', u'optical'): [u'want'],
#  (u'bought', u'with'): [u'another'],
#  (u'pda', u'and'): [u'owner'],
#  (u'storage', u'and'): [u'capacity'],
#  (u'you', u'each'): [u'hear'],
#  (u"n't", u'track'): [u'lose'],
#  (u'.', u'switching'): [u'after', u'this'],
#  (u"n't", u'scratches'): [u'produce'],
#  (u',', u'text'): [u'all'],
#  (u'by', u'coordinates'): [u'using'],
#  (u'warranty', u'a'): [u'and'],
#  (u'bonus', u'wel'): [u'as'],
#  (u',', u'processing'): [u'word'],
#  (u'stood', u','): [u'up'],
#  (u'with', u'major'): [u'no'],
#  (u'precise', u'responsive'): [u'and'],
#  (u'they', u'.'): [u'off', u'do', u'offer', u'say', u'purchased'],
#  (u'this', u'doohickey'): [u'little'],
#  (u'along', u'many'): [u'on'],
#  (u'all', u'keyboard'): [u'around'],
#  (u'those', u'with'): [u'unsatisfied', u'others'],
#  (u'inkjet', u"n't"): [u'dose'],
#  (u'wo', u'see'): [u"n't"],
#  (u'cup', u'adapter'): [u'charge'],
#  (u"'toys", u'that'): [u"'"],
#  (u'its', u'counterparts'): [u'older', u'digital'],
#  (u'with', u'white'): [u'my'],
#  (u'hold', u'of'): [u'variety'],
#  (u'heart-attack', u'its'): [u'.'],
#  (u'got', u'with'): [u'is'],
#  (u'or', u'to'): [u'like',
#   u'three',
#   u'tv',
#   u'listening',
#   u'want',
#   u'learn',
#   u'two',
#   u'cellar',
#   u'two',
#   u'only',
#   u'like'],
#  (u'protective', u'that'): [u'case'],
#  (u'which', u'your'): [u'gives'],
#  (u'radio', u'great'): [u'is', u'is'],
#  (u'are', u'down/banana'): [u'screw'],
#  (u'subtle', u'for'): [u'pressure'],
#  (u'vehicles', u'a'): [u'.'],
#  (u'happy', u'purchased'): [u'i'],
#  (u'nightstand', u'am'): [u'and'],
#  (u'needless', u'say'): [u'to', u'to'],
#  (u'hours', u'.'): [u')'],
#  (u'most', u'papers'): [u'photo'],
#  (u'which', u'currently'): [u'is'],
#  (u'``', u'base'): [u'knowledge'],
#  (u'bought', u'item'): [u'an', u'this', u'this'],
#  (u'and', u'absolutely'): [u'i'],
#  (u'my', u'table'): [u'computer', u'tray'],
#  (u'loved', u'so'): [u'it'],
#  (u'dry', u'they'): [u'after', u'and'],
#  (u':', u"'m"): [u'i'],
#  (u'so', u'from'): [u'easily'],
#  (u'separate', u'calendar'): [u'pocket'],
#  (u'area', u'the'): [u'.', u'of', u'on'],
#  (u'an', u'tuner'): [u'hdtv'],
#  (u'cop', u'.'): [u'ahead'],
#  (u'space', u'trust'): [u'.'],
#  (u'language', u'card'): [u'installation'],
#  (u'and', u'each'): [u'offsets'],
#  (u'being', u'steal'): [u'a'],
#  (u'make', u'info'): [u'this'],
#  (u'no', u'under'): [u'boxes'],
#  (u'package', u'bought'): [u'i'],
#  (u'examines', u'with'): [u'you'],
#  (u',', u'three'): [u'took'],
#  (u'or', u'being'): [u'ever'],
#  (u'is', u'brightness'): [u'the'],
#  (u'camcorder', u'up'): [u'hooks'],
#  (u'transferred', u'quickly'): [u'reasonably'],
#  (u'review', u'without'): [u'anything'],
#  (u'have', u'vosky'): [u'used'],
#  (u'1', u'memory'): [u'gb'],
#  (u'bass', u'lot'): [u'a'],
#  (u'same', u'the'): [u'.'],
#  (u'it', u'simple'): [u'for', u'was'],
#  (u'than', u'sharp'): [u'the'],
#  (u'is', u'samsung'): [u'a'],
#  (u'was', u'brezz'): [u'a'],
#  (u'things', u'intending'): [u'anyone'],
#  (u'well', u'.'): [u')',
#   u'built',
#   u'planned',
#   u'built',
#   u'made',
#   u'spent',
#   u'organized',
#   u'absorbed'],
#  (u'scratched', u'quite'): [u'it'],
#  (u'manages', u'.'): [u'geocaches'],
#  (u'up', u'right'): [u'just'],
#  (u'spare', u'headset'): [u'bluetooth'],
#  (u'scream', u"'s"): [u"'there"],
#  (u'have', u'running'): [u'cables'],
#  (u'expectations', u'while'): [u'.'],
#  (u',', u'fuss'): [u'no'],
#  (u'weekend', u'and'): [u'photographing'],
#  (u'when', u'was'): [u'it',
#   u'that',
#   u'i',
#   u'i',
#   u'i',
#   u'i',
#   u'it',
#   u'i',
#   u'there'],
#  (u'everyday', u'around'): [u'mousing'],
#  (u'session', u'i'): [u','],
#  (u'that', u'promised'): [u'it'],
#  (u'anywhere', u'my'): [u'in'],
#  (u'card', u'compusa'): [u'at'],
#  (u'memory', u'i'): [u'card', u'sticks'],
#  (u'controller', u'it'): [u'.'],
#  (u'keep', u'on'): [u'these'],
#  (u'i', u'willing'): [u'was'],
#  (u'with', u'mini'): [u'my'],
#  (u'folks', u'hilly'): [u'in'],
#  (u'buy', u'service'): [u'this', u'this'],
#  (u'lane', u','): [u')'],
#  (u'powerful', u'any'): [u'as'],
#  (u'accidentaly', u'on'): [u'sat'],
#  (u'external', u'powered'): [u'('],
#  (u'you', u'wep'): [u'enable'],
#  (u'problems', u'either'): [u'with'],
#  (u'positive', u','): [u'feature', u'reviews'],
#  (u'wow', u'who'): [u','],
#  (u'somewhere', u'walking'): [u'or'],
#  (u'others', u'experienced'): [u'have'],
#  (u'if', u'pivoting'): [u'the'],
#  (u'handset', u'helped'): [u'has'],
#  (u'gotten', u'good'): [u'very'],
#  (u'others', u'said'): [u'have', u'have'],
#  (u'fuss', u'text'): [u'.'],
#  (u'well', u'--'): [u')'],
#  (u'in', u'close'): [u'a'],
#  (u'been', u'pleased'): [u'very', u'very', u'very', u'quite'],
#  (u'a', u'mouse'): [u'giant',
#   u'bt',
#   u'good',
#   u'second',
#   u'corded',
#   u'cordless',
#   u'wireless',
#   u'full-size',
#   u'normal',
#   u'wider',
#   u'comfortable'],
#  (u'other', u'such'): [u'resources'],
#  (u'.', u'definite'): [u'a'],
#  (u'in', u'previous'): [u'my'],
#  (u'not', u'same'): [u'the', u'the'],
#  (u'bought', u'1000mah'): [u'4'],
#  (u'love', u'thing'): [u'this'],
#  (u'things', u'your'): [u'while'],
#  (u'holds', u'400'): [u'over'],
#  (u'than', u'$'): [u'my'],
#  (u'use', u'&'): [u'itunes'],
#  (u'attached', u'.'): [u'to'],
#  (u'than', u'artist'): [u'the'],
#  (u'sound', u'low'): [u'for'],
#  (u'need', u'say'): [u'to'],
#  (u'.', u'sony'): [u'this', u'my', u'the'],
#  (u',', u'outweighed'): [u'far'],
#  (u'height', u'2.5'): [u'at'],
#  (u'during', u'outages'): [u'power', u'power', u'power'],
#  (u'as', u'still'): [u'they'],
#  (u'performs', u'better'): [u'no'],
#  (u'for', u'periods'): [u'long', u'extended', u'extended'],
#  (u'like', u'audigy'): [u'the'],
#  (u'.', u'type'): [u'those'],
#  (u'all', u'it'): [u'that', u',', u'that', u'of', u'because'],
#  (u'operations', u'a'): [u'have'],
#  (u'one', u'settle'): [u'will'],
#  (u'watch', u'in'): [u'tv'],
#  (u'sport', u'which'): [u','],
#  (u"'s", u'album'): [u'eponymous', u'3rd'],
#  (u'do', u'again-thanks'): [u'business'],
#  (u'not', u'trusted'): [u'be'],
#  (u'2.', u'controls'): [u'the'],
#  (u'have', u'desk'): [u'the'],
#  (u'button', u'to'): [u'switch'],
#  (u'i', u'together'): [u'put'],
#  (u'bought', u'linksys'): [u'a'],
#  (u'has', u'component'): [u'3'],
#  (u'in', u'key'): [u'the'],
#  (u"n't", u'myself'): [u'consider'],
#  (u'just', u'made'): [u'have'],
#  (u'on', u'battery'): [u'aa'],
#  (u'how', u'gravis'): [u'my'],
#  (u'really', u'mp3'): [u'expensive', u'expensive'],
#  (u'should', u'one'): [u'have'],
#  (u'e30s', u'heavy'): [u'are'],
#  (u'depth', u'and'): [u','],
#  (u'they', u'all'): [u'see', u'are', u'break', u'are'],
#  (u'.', u'quick'): [u'the', u'the'],
#  (u'cam', u'it'): [u'and'],
#  (u'controls', u'is'): [u'layout'],
#  (u'into', u'system'): [u'this'],
#  (u'picked', u'the'): [u'up'],
#  (u'calls', u'one'): [u'.'],
#  (u'that', u'monitor'): [u'this'],
#  (u'prepared', u'see'): [u'to'],
#  (u'patch', u'('): [u'cables'],
#  (u'which', u'forced'): [u'have'],
#  (u'office', u'the'): [u'.'],
#  (u'preceded', u'followed'): [u'or'],
#  (u'did', u'off'): [u'break', u'fall'],
#  (u'product', u'without'): [u'and'],
#  (u':', u'2.0'): [u'usb'],
#  (u'for', u'compatibility'): [u'it'],
#  (u'capabilities', u'this'): [u'('],
#  (u'awesome', u'my'): [u'from'],
#  (u'remember', u'some'): [u'that'],
#  (u'so', u'appeared'): [u'far'],
#  (u'hinder', u','): [u'performance'],
#  (u'it', u'nfs'): [u'in'],
#  (u',', u'neck'): [u'your'],
#  (u'the', u'gear'): [u'plastic'],
#  (u'of', u'aiming'): [u'mouse'],
#  (u'store', u'1000'): [u'over'],
#  (u'separate', u'source'): [u'power'],
#  (u'unit', u'much'): [u'is'],
#  (u'that', u'by'): [u'paper'],
#  (u'purchased', u'g7'): [u'my'],
#  (u'leave', u'to'): [u'affixed'],
#  (u'pain', u'my'): [u'in'],
#  (u'instant', u'('): [u'messenger'],
#  (u'imac', u"''"): [u'w/20', u'20'],
#  (u'tone', u'this'): [u'.'],
#  (u'house', u'we'): [u'so', u'so'],
#  (u'short', u'after'): [u','],
#  (u'like', u'128mb'): [u'most'],
#  (u'6.1', u'theater'): [u'home'],
#  (u'!', u'brought'): [u'they'],
#  (u'make', u'photo'): [u'fabulous'],
#  (u'about', u'scratching'): [u'it'],
#  (u'that', u'address'): [u'ip'],
#  (u'ports', u'my'): [u'.'],
#  (u'any', u'near'): [u'where'],
#  (u',', u'1030'): [u'the'],
#  (u'included', u':'): [u'overall', u'are'],
#  (u'to', u'hard'): [u'your', u'a'],
#  (u'desktop', u'and'): [u'unit'],
#  (u'have', u'write'): [u'to'],
#  (u'you', u'overlook'): [u'can'],
#  (u'and', u'company'): [u'phone'],
#  (u'much', u'then'): [u'longer', u'better'],
#  (u'quality', u'performance'): [u'and', u'in'],
#  (u'the', u'number'): [u'wide', u'same'],
#  (u'case', u'reader'): [u'keeps'],
#  (u'with', u'device'): [u'every', u'the'],
#  (u'as', u'demand'): [u'the'],
#  (u'detailed', u':'): [u'review'],
#  (u'takes', u'mimimum'): [u'a'],
#  (u'confident', u'that'): [u'on'],
#  (u'changed', u'this'): [u'.'],
#  (u'of', u'cents'): [u'40', u'12'],
#  (u'so', u'do'): [u'i',
#   u'i',
#   u'i',
#   u'they',
#   u'i',
#   u'they',
#   u'you',
#   u'i',
#   u'i',
#   u'i',
#   u'i',
#   u'you',
#   u'i',
#   u'you'],
#  (u'pleasantly', u'.'): [u'surprised', u'surprised'],
#  (u'viewsonic', u'xp'): [u'('],
#  (u'.', u'enclosed'): [u'an'],
#  (u'out', u'background'): [u'the'],
#  (u'indeed', u'in'): [u'.'],
#  (u'enter', u'.'): [u'stuff'],
#  (u'first', u'speakers'): [u'logitech'],
#  (u'do', u'work'): [u'their', u'your', u"n't", u'not'],
#  (u'tunecast', u'a'): [u'is'],
#  (u'the', u'guide'): [u'users', u'users', u'troubleshooting'],
#  (u'definitely', u'this'): [u'recommend', u'recommend', u'recommend'],
#  (u'polycom', u'will'): [u'communicator'],
#  (u'charge', u','): [u'quickly', u'it'],
#  (u'the', u"'case"): [u'included'],
#  (u'with', u'lanyard'): [u'the'],
#  (u'from', u'sub'): [u'the'],
#  (u'need', u'power'): [u'a'],
#  (u'have', u'signal'): [u'light'],
#  (u'fix', u'worn-out'): [u'its'],
#  (u'cons', u'*'): [u':'],
#  (u'it', u'torture'): [u'was'],
#  (u'100', u'these'): [u'of'],
#  (u'i', u'v8'): [u'ordered'],
#  (u'--', u'find'): [u'i'],
#  (u'mouse', u'but'): [u',', u','],
#  (u'movies', u'some'): [u'('],
#  (u'1.1', u'with'): [u'ships'],
#  (u'and', u'may'): [u'you', u'you', u'i'],
#  (u'lamp', u'a'): [u'and'],
#  (u'.', u'imaging'): [u'spacial/stereo'],
#  (u'connect', u'pico'): [u'the'],
#  (u'not', u'cars'): [u'hear'],
#  (u't5820', u'radios'): [u'2-way'],
#  (u'connect', u'distant'): [u'a'],
#  (u'public', u'.'): [u'places'],
#  (u'you', u'in'): [u'hear',
#   u'are',
#   u'heard',
#   u'are',
#   u'walk',
#   u'are',
#   u'record',
#   u'invest',
#   u'are',
#   u'ipod',
#   u'i-pod',
#   u'plug',
#   u'are',
#   u'zoom'],
#  (u'bit', u'than'): [u'longer',
#   u'wider',
#   u'smaller',
#   u'more',
#   u'more',
#   u'larger'],
#  (u'dj', u'in'): [u'headphones'],
#  (u'way', u'least'): [u'at'],
#  (u'did', u'worry'): [u"n't"],
#  (u'been', u'on'): [u'along', u'going'],
#  (u'bass', u'you'): [u'.'],
#  (u'condition', u'will'): [u','],
#  (u'are', u'better'): [u'much', u'far'],
#  (u'another', u'by'): [u'buyout'],
#  (u'shake', u'cartrige'): [u'the'],
#  (u'glad', u'pay'): [u'to'],
#  (u'and', u'fair'): [u'a'],
#  (u'.', u'built-in'): [u'the'],
#  (u'the', u'tunecok'): [u'white'],
#  (u'find', u'i'): [u'that'],
#  (u'holding', u'.'): [u'button'],
#  (u'investment', u'my'): [u'in'],
#  (u'picture', u'this'): [u'with'],
#  (u'with', u'webcams'): [u'their'],
#  (u'for', u'457'): [u'the'],
#  (u'as', u'accurate'): [u'being'],
#  (u',', u'dvd-audio'): [u'prefer'],
#  (u'for', u'stuff'): [u'other'],
#  (u'read-speed', u'these'): [u'on'],
#  (u'unit', u'highly'): [u'a'],
#  (u'2003', u'movie'): [u'when'],
#  (u"'s", u'paper'): [u'photo', u'own'],
#  (u'in', u'reviews'): [u'previous', u'their'],
#  (u'and', u'products'): [u'the'],
#  (u'sized', u'all'): [u'sub-woofer'],
#  (u'carry', u'ipod'): [u'your'],
#  (u'm7480n', u'center'): [u'media'],
#  (u'black', u'with'): [u'case', u'car'],
#  (u'drive', u'worth'): [u'.'],
#  (u'voice', u'working'): [u'is'],
#  (u'or', u'dvds'): [u'+r'],
#  (u'car', u'as'): [u'.'],
#  (u'exact', u'the'): [u'city'],
#  (u"'m", u'two'): [u'running'],
#  (u'price', u'have'): [u'i', u'i'],
#  (u'agree', u'the'): [u'that', u'with', u'with', u'with'],
#  (u'very', u'subtle'): [u'very'],
#  (u'into', u'usb'): [u'two',
#   u'your',
#   u'your',
#   u'a',
#   u'the',
#   u'the',
#   u'the',
#   u'the'],
#  (u'truly', u'at'): [u'amazed'],
#  (u'people', u'a'): [u'no', u'waiting'],
#  (u'-', u'value'): [u'great'],
#  (u'couple', u'&'): [u'dvrs'],
#  (u'soundcard', u'and'): [u'jack'],
#  (u'dial', u'are'): [u'buttons'],
#  (u'racing', u'they'): [u'as'],
#  (u'they', u'one'): [u"'re", u'are'],
#  (u'more', u'.'): [u'attention',
#   u'so',
#   u'thing',
#   u'easily',
#   u'straightforward',
#   u'expensive',
#   u'space',
#   u'appropriate',
#   u'money',
#   u'expensive',
#   u'details',
#   u'congestion',
#   u'sold',
#   u'noise',
#   u'data',
#   u'expensive',
#   u')',
#   u'efficently'],
#  (u'wheel', u'that'): [u'from'],
#  (u'remote', u'are'): [u'monitoring'],
#  (u'with', u'.'): [u'happiness',
#   u'it',
#   u'quality',
#   u'it',
#   u'd-link',
#   u'it',
#   u'them',
#   u'winamp',
#   u'it',
#   u'you',
#   u'it',
#   u'eq',
#   u'care',
#   u'macs',
#   u'me',
#   u'it',
#   u'this',
#   u'it',
#   u'that',
#   u'amazon.com',
#   u'that',
#   u'skype',
#   u'it',
#   u'w2k',
#   u'you',
#   u'it',
#   u'it',
#   u'it',
#   u'it',
#   u'klipsch',
#   u'them',
#   u'it',
#   u'it',
#   u'confidence',
#   u'it',
#   u'it',
#   u'it',
#   u'booklets',
#   u'it',
#   u'ease',
#   u'it',
#   u'either',
#   u'it',
#   u'it',
#   u'unit',
#   u'it',
#   u'install',
#   u'time',
#   u'it',
#   u'it',
#   u'it',
#   u'that',
#   u'it',
#   u'it',
#   u'it',
#   u'it',
#   u'me',
#   u'it',
#   u'it',
#   u'signal'],
#  (u'only', u'antenna'): [u'the'],
#  (u'look', u'their'): [u'for'],
#  (u'us', u'canada'): [u'and'],
#  (u'mention', u'it'): [u'that'],
#  (u'install', u'then'): [u'and'],
#  (u'is', u'alot'): [u'also'],
#  (u'unlock', u'that'): [u'code', u'on'],
#  (u'with', u'macintosh'): [u'my'],
#  (u'get', u'and'): [u'price', u'lost', u'on'],
#  (u'xpc', u'sb75g2'): [u'('],
#  (u'shooter', u'like'): [u'games'],
#  (u'no', u'demon'): [u'speed'],
#  (u'nor', u'wife'): [u'my'],
#  (u'record', u'sound'): [u'the'],
#  (u'cd', u'and'): [u'cases', u"'s", u'players', u'player', u'player'],
#  (u'(', u'always'): [u'i'],
#  (u':', u'reliable'): [u'small'],
#  (u'competition', u'the'): [u'in'],
#  (u'use', u'printer'): [u'this'],
#  (u'black', u'holds'): [u'and'],
#  (u'into', u'easily'): [u'pockets'],
#  (u'it', u'game'): [u','],
#  (u'keyboards', u'than'): [u'sooner'],
#  (u'lcds', u'do'): [u'just'],
#  (u'gb', u','): [u'mp3'],
#  (u'in', u'return'): [u'a'],
#  (u'what', u'with'): [u'familiar'],
#  (u'a', u'instead'): [u'star', u'4'],
#  (u'buy', u'tape'): [u'a'],
#  (u'the', u'onto'): [u'itrip'],
#  (u'unit', u'find'): [u'to'],
#  (u'response', u'on'): [u'program'],
#  (u'you', u'talk'): [u'can'],
#  (u'are', u'tivo'): [u'using'],
#  (u'x-plane', u'works'): [u','],
#  (u'as', u'read'): [u'i'],
#  (u'is', u'vpn'): [u'that'],
#  (u'water', u'enough'): [u'it'],
#  (u'unit', u'locate'): [u'to'],
#  (u'superoposterior', u'of'): [u'part'],
#  (u'because', u'keep'): [u'it'],
#  (u'live', u'it'): [u'with'],
#  (u'someone', u'to'): [u'looking', u'forgot', u'next'],
#  (u'non', u'paper'): [u'epson'],
#  (u'imagine', u'more'): [u'spending'],
#  (u'just', u'for'): [u'fine', u'fine', u'looking', u'perfect'],
#  (u'of', u'gps'): [u'the'],
#  (u'antenna', u'worth'): [u'was'],
#  (u'since', u'scratch'): [u'they'],
#  (u'it', u"'"): [u'away', u'in'],
#  (u'use', u'syncs'): [u'and'],
#  (u'purchasing', u'tamrac'): [u'the'],
#  (u'always', u'to'): [u'easy', u'go', u'want', u'better', u'do', u'try'],
#  (u'get', u'handset'): [u'the'],
#  (u'and', u'phones'): [u'standard'],
#  (u'technical', u'for'): [u'names'],
#  (u'five', u'ago'): [u'years'],
#  (u'selectivity', u'please'): [u'.'],
#  (u'i', u'cases'): [u'researched'],
#  (u'it', u'heavy'): [u"'s", u'is', u'pretty'],
#  (u'streets', u'however'): [u'.'],
#  (u'which', u'renders'): [u'occasionnally'],
#  (u'asa', u'c\ufffdmoda'): [u'es'],
#  (u'super', u'out'): [u'video'],
#  (u"'", u'make'): [u'switch'],
#  (u'miss', u'thing'): [u'a'],
#  (u'phone', u'('): [u'system'],
#  (u'one', u'trying'): [u'is'],
#  (u'boards', u'record'): [u'to'],
#  (u'the', u'gateway'): [u'default'],
#  (u'aggravating', u'woes'): [u'support'],
#  (u'expected', u'.'): [u'results', u'time'],
#  (u'fix', u'.'): [u'it'],
#  (u'over', u'brands'): [u'different'],
#  (u',', u'resolution'): [u'high'],
#  (u'documents', u'my'): [u',', u'before'],
#  (u'received', u'correct'): [u'the'],
#  (u'info', u'automatically'): [u'to'],
#  (u'lens', u'dust'): [u'from'],
#  (u'in', u'promedia'): [u'the'],
#  (u'size', u'since'): [u'and'],
#  (u'the', u'mp3'): [u'first'],
#  (u',', u'ex71'): [u'sony'],
#  (u'is', u'wireless'): [u'the'],
#  (u'friend', u'maybe'): [u'...'],
#  (u'it', u'.they'): [u'...'],
#  (u'of', u'where'): [u'metal', u'computers'],
#  (u'to', u'instructions'): [u'read', u'the'],
#  (u'finally', u'no'): [u','],
#  (u'from', u'name'): [u'a'],
#  (u'over', u'dvd-ram'): [u'50'],
#  (u'and', u'monitor'): [u'lcd', u'the'],
#  (u'product', u'seems'): [u'itself'],
#  (u'live', u'an'): [u'in'],
#  (u'quality', u'surprisingly'): [u'is'],
#  ...}

# %%
trigrams_probabilities = {}
for k, words in trigrams.iteritems():
    if len(set(words)) > 1:
        d = {}
        n = 0
        for w in words:
            if w not in d:
                d[w] = 0
            d[w] +=1
            n+=1
        for w,c in d.iteritems():
            d[w] = float(c) / n
        trigrams_probabilities[k] = d

# %%
trigrams_probabilities
# Out:
# {(u',', u'which'): {u"''": 0.3333333333333333,
#   u'(': 0.3333333333333333,
#   u'and': 0.3333333333333333},
#  (u'to', u'i'): {u',': 0.09090909090909091,
#   u'.': 0.2727272727272727,
#   u'bed': 0.09090909090909091,
#   u'but': 0.09090909090909091,
#   u'it': 0.09090909090909091,
#   u'say': 0.18181818181818182,
#   u'wherever': 0.09090909090909091,
#   u'which': 0.09090909090909091},
#  (u'in', u'usb'): {u'another': 0.3333333333333333, u'the': 0.6666666666666666},
#  (u'you', u'have'): {u"'ll": 0.2222222222222222,
#   u'also': 0.037037037037037035,
#   u'always': 0.037037037037037035,
#   u'can': 0.037037037037037035,
#   u'definitely': 0.037037037037037035,
#   u'do': 0.037037037037037035,
#   u'may': 0.07407407407407407,
#   u'might': 0.1111111111111111,
#   u'must': 0.037037037037037035,
#   u'never': 0.037037037037037035,
#   u'now': 0.037037037037037035,
#   u'only': 0.037037037037037035,
#   u'should': 0.037037037037037035,
#   u'to': 0.037037037037037035,
#   u'will': 0.1111111111111111,
#   u'wont': 0.037037037037037035,
#   u'would': 0.037037037037037035},
#  (u'in', u'movie'): {u'a': 0.5, u'windows': 0.5},
#  (u'between', u'and'): {u',': 0.125,
#   u'cable': 0.125,
#   u'fm': 0.125,
#   u'it': 0.125,
#   u'this': 0.25,
#   u'touchpad': 0.125,
#   u'verbatim': 0.125},
#  (u'i', u'running'): {u"'m": 0.6, u'am': 0.2, u'was': 0.2},
#  (u'a', u'this'): {u'bit': 0.3333333333333333,
#   u'device': 0.3333333333333333,
#   u'screen': 0.3333333333333333},
#  (u'could', u'find'): {u"n't": 0.75, u'not': 0.25},
#  (u'have', u'made'): {u'also': 0.5, u'been': 0.5},
#  (u'product', u'worth'): {u'.': 0.5, u'is': 0.5},
#  (u'it', u'put'): {u"'d": 0.5, u'stays': 0.5},
#  (u'line', u'the'): {u'(': 0.2,
#   u'and': 0.2,
#   u'from': 0.2,
#   u'on': 0.2,
#   u'to': 0.2},
#  (u'just', u'my'): {u'got': 0.4,
#   u'recieved': 0.2,
#   u'removed': 0.2,
#   u'take': 0.2},
#  (u'person', u'a'): {u'dealing': 0.3333333333333333,
#   u'in': 0.6666666666666666},
#  (u'want', u'you'): {u'everytime': 0.5, u'optical': 0.5},
#  (u'think', u'are'): {u'there': 0.5, u'these': 0.5},
#  (u'for', u'mp3'): {u'my': 0.5, u'storing': 0.5},
#  (u'is', u'.'): {u'amazing': 0.06896551724137931,
#   u'approx': 0.008620689655172414,
#   u'asleep': 0.008620689655172414,
#   u'astonishing': 0.008620689655172414,
#   u'at': 0.008620689655172414,
#   u'attractive': 0.008620689655172414,
#   u'awesome': 0.02586206896551724,
#   u'bad': 0.008620689655172414,
#   u'better': 0.017241379310344827,
#   u'calling': 0.008620689655172414,
#   u'canon': 0.008620689655172414,
#   u'cool': 0.008620689655172414,
#   u'delivering': 0.008620689655172414,
#   u'docked': 0.008620689655172414,
#   u'easy': 0.008620689655172414,
#   u'empty': 0.008620689655172414,
#   u'essential': 0.008620689655172414,
#   u'excellent': 0.08620689655172414,
#   u'expensive': 0.008620689655172414,
#   u'fast': 0.008620689655172414,
#   u'faxing': 0.008620689655172414,
#   u'fine': 0.017241379310344827,
#   u'flawed': 0.008620689655172414,
#   u'good': 0.02586206896551724,
#   u'great': 0.15517241379310345,
#   u'handy': 0.008620689655172414,
#   u'helpful': 0.008620689655172414,
#   u'high': 0.008620689655172414,
#   u'idle': 0.008620689655172414,
#   u'inline': 0.008620689655172414,
#   u'insane': 0.008620689655172414,
#   u'it': 0.008620689655172414,
#   u'killer': 0.008620689655172414,
#   u'large': 0.008620689655172414,
#   u'lighting': 0.008620689655172414,
#   u'limited': 0.008620689655172414,
#   u'lost': 0.008620689655172414,
#   u'loud': 0.008620689655172414,
#   u'low': 0.017241379310344827,
#   u'marvelous': 0.008620689655172414,
#   u'mediocre': 0.008620689655172414,
#   u'minimal': 0.008620689655172414,
#   u'necessary': 0.008620689655172414,
#   u'nice': 0.008620689655172414,
#   u'not': 0.008620689655172414,
#   u'obvious': 0.008620689655172414,
#   u'off': 0.02586206896551724,
#   u'okay': 0.008620689655172414,
#   u'on': 0.017241379310344827,
#   u'organized': 0.008620689655172414,
#   u'outstanding': 0.008620689655172414,
#   u'over': 0.008620689655172414,
#   u'perfect': 0.008620689655172414,
#   u'playing': 0.008620689655172414,
#   u'possible': 0.008620689655172414,
#   u'present': 0.008620689655172414,
#   u'recommended': 0.008620689655172414,
#   u'slow': 0.008620689655172414,
#   u'so-so': 0.008620689655172414,
#   u'superb': 0.02586206896551724,
#   u'terrific': 0.017241379310344827,
#   u'top': 0.008620689655172414,
#   u'unfair': 0.008620689655172414,
#   u'unobtrusive': 0.008620689655172414,
#   u'useful': 0.008620689655172414,
#   u'weak': 0.008620689655172414,
#   u'wonderful': 0.034482758620689655},
#  (u'!', u'for'): {u'and': 0.25, u'now': 0.25, u'perfect': 0.5},
#  (u'.', u'would'): {u'filtering': 0.01818181818181818,
#   u'i': 0.7272727272727273,
#   u'it': 0.09090909090909091,
#   u'probably': 0.01818181818181818,
#   u'product': 0.01818181818181818,
#   u'that': 0.01818181818181818,
#   u'this': 0.03636363636363636,
#   u'we': 0.01818181818181818,
#   u'white': 0.01818181818181818,
#   u'you': 0.03636363636363636},
#  (u'on', u'computer'): {u'my': 0.5454545454545454,
#   u'the': 0.2727272727272727,
#   u'your': 0.18181818181818182},
#  (u'screen', u'the'): {u'!': 0.1111111111111111,
#   u',': 0.2222222222222222,
#   u'.': 0.3333333333333333,
#   u'displays': 0.1111111111111111,
#   u'or': 0.1111111111111111,
#   u'than': 0.1111111111111111},
#  (u',', u'sound'): {u'a': 0.05,
#   u'and': 0.05,
#   u'but': 0.05,
#   u'crisp': 0.05,
#   u'good': 0.05,
#   u'hissing': 0.05,
#   u'incredible': 0.05,
#   u'natural': 0.1,
#   u'the': 0.45,
#   u'they': 0.05,
#   u'uncolored': 0.05},
#  (u'a', u'headset'): {u'good': 0.16666666666666666,
#   u'great': 0.3333333333333333,
#   u'nice': 0.16666666666666666,
#   u'usb': 0.16666666666666666,
#   u'wonderful': 0.16666666666666666},
#  (u'at', u'times'): {u'all': 0.75, u'three': 0.25},
#  (u'than', u'having'): {u'just': 0.5, u'not': 0.5},
#  (u'receiver', u'tv'): {u',': 0.5, u'and': 0.5},
#  (u'and', u'that'): {u'clear': 0.037037037037037035,
#   u'feel': 0.037037037037037035,
#   u'for': 0.07407407407407407,
#   u'found': 0.14814814814814814,
#   u'get': 0.037037037037037035,
#   u'if': 0.07407407407407407,
#   u'install': 0.037037037037037035,
#   u'just': 0.037037037037037035,
#   u'notice': 0.037037037037037035,
#   u'now': 0.037037037037037035,
#   u'one': 0.037037037037037035,
#   u'pictures': 0.037037037037037035,
#   u'portablility': 0.037037037037037035,
#   u'receivers': 0.037037037037037035,
#   u'saw': 0.037037037037037035,
#   u'sensitivity': 0.037037037037037035,
#   u'thought': 0.037037037037037035,
#   u'trouble-shooters': 0.037037037037037035,
#   u'understand': 0.037037037037037035,
#   u'use': 0.037037037037037035,
#   u'uses': 0.037037037037037035,
#   u'wire': 0.037037037037037035},
#  (u'quality', u'great'): {u';': 0.1, u'is': 0.9},
#  (u'feel', u'this'): {u'.': 0.5, u'that': 0.5},
#  (u'and', u'brand'): {u'another': 0.3333333333333333,
#   u'the': 0.3333333333333333,
#   u'this': 0.3333333333333333},
#  (u'.', u'cost'): {u'huge': 0.3333333333333333,
#   u'low': 0.3333333333333333,
#   u'the': 0.3333333333333333},
#  (u'is', u'detachable'): {u'a': 0.5, u'not': 0.5},
#  (u"'", u'their'): {u'down': 0.5, u'on': 0.5},
#  (u'worried', u'the'): {u'about': 0.5, u'that': 0.5},
#  (u':', u'a'): {u'seems': 0.5, u'with': 0.5},
#  (u',', u'hiss'): {u'background': 0.5, u'the': 0.5},
#  (u'played', u'on'): {u'fine': 0.5, u'once': 0.5},
#  (u'headphones', u'this'): {u',': 0.25, u'.': 0.25, u'in': 0.5},
#  (u'the', u'wheel'): {u'click': 0.1111111111111111,
#   u'optical': 0.1111111111111111,
#   u'scroll': 0.5555555555555556,
#   u'steering': 0.2222222222222222},
#  (u'a', u'version'): {u'bluetooth': 0.3333333333333333,
#   u'newer': 0.3333333333333333,
#   u'rubber': 0.3333333333333333},
#  (u'me', u'not'): {u'.': 0.6666666666666666, u'was': 0.3333333333333333},
#  (u'--', u'i'): {u'-': 0.5, u'if': 0.5},
#  (u'.', u'very'): {u'a': 0.2, u'also': 0.4, u'its': 0.2, u'provides': 0.2},
#  (u'actually', u'this'): {u'bought': 0.5, u'like': 0.5},
#  (u'so', u"'ve"): {u'i': 0.5, u'you': 0.5},
#  (u'have', u'unit'): {u'my': 0.5, u'the': 0.5},
#  (u'the', u'cd'): {u'first': 0.3333333333333333,
#   u'included': 0.3333333333333333,
#   u'phonetools': 0.3333333333333333},
#  (u'simple', u'that'): {u'as': 0.3333333333333333,
#   u'enough': 0.3333333333333333,
#   u'product': 0.3333333333333333},
#  (u'by', u'this'): {u'making': 0.5, u'recommending': 0.5},
#  (u'a', u'game'): {u'linksys': 0.3333333333333333, u'pc': 0.6666666666666666},
#  (u'probably', u'it'): {u'fixed': 0.5, u'worth': 0.5},
#  (u'no', u'screen'): {u'a': 0.5, u'lcd': 0.5},
#  (u'without', u','): {u'bubbles': 0.2,
#   u'charging': 0.4,
#   u'input': 0.2,
#   u'music': 0.2},
#  (u'cable', u'the'): {u'.': 0.125,
#   u'and': 0.25,
#   u'for': 0.25,
#   u'into': 0.125,
#   u'to': 0.25},
#  (u'about', u"'s"): {u'it': 0.5, u'viewsonic': 0.5},
#  (u'gets', u'stars'): {u'5': 0.5, u'four': 0.5},
#  (u'sheet', u'a'): {u'!': 0.5, u'covers': 0.5},
#  (u'my', u'laptop'): {u'dell': 0.14285714285714285,
#   u'g4': 0.14285714285714285,
#   u'hp': 0.14285714285714285,
#   u'non-bluetooth-enabled': 0.14285714285714285,
#   u'other': 0.14285714285714285,
#   u'precious': 0.14285714285714285,
#   u'versatile': 0.14285714285714285},
#  (u'my', u'digital'): {u'canon': 0.3333333333333333,
#   u'first': 0.3333333333333333,
#   u'g/friends': 0.3333333333333333},
#  (u'have', u'tried'): {u"n't": 0.6666666666666666,
#   u'never': 0.16666666666666666,
#   u'not': 0.16666666666666666},
#  (u'an', u'power'): {u'external': 0.5, u'irregular': 0.5},
#  (u'my', u'a'): {u'car': 0.25, u'game': 0.25, u'rebate': 0.25, u'thumb': 0.25},
#  (u'cd', u'the'): {u'in': 0.3333333333333333,
#   u'or': 0.3333333333333333,
#   u'reveal': 0.3333333333333333},
#  (u',', u'comfort'): {u'and': 0.3333333333333333,
#   u'great': 0.3333333333333333,
#   u'the': 0.3333333333333333},
#  (u'i', u'put'): {u"'ve": 0.14285714285714285,
#   u'also': 0.2857142857142857,
#   u'can': 0.14285714285714285,
#   u'could': 0.14285714285714285,
#   u'only': 0.14285714285714285,
#   u'would': 0.14285714285714285},
#  (u',', u'keys'): {u'insert/delete': 0.5, u'the': 0.5},
#  (u"n't", u'out'): {u'drowning': 0.1111111111111111,
#   u'fall': 0.1111111111111111,
#   u'figure': 0.1111111111111111,
#   u'figured': 0.2222222222222222,
#   u'protrude': 0.1111111111111111,
#   u'run': 0.1111111111111111,
#   u'wash': 0.1111111111111111,
#   u'wear': 0.1111111111111111},
#  (u'with', u'wireless'): {u'a': 0.25, u'most': 0.25, u'my': 0.5},
#  (u',', u'frequency'): {u'low': 0.5, u'the': 0.5},
#  (u'but', u'soon'): {u'as': 0.5, u'i': 0.5},
#  (u'best', u'to'): {u'bass': 0.25, u'way': 0.75},
#  (u'it', u'me'): {u'allows': 0.08333333333333333,
#   u'blows': 0.08333333333333333,
#   u'let': 0.08333333333333333,
#   u'saved': 0.08333333333333333,
#   u'scolds': 0.08333333333333333,
#   u'to': 0.16666666666666666,
#   u'took': 0.4166666666666667},
#  (u'my', u'...'): {u'friend': 0.3333333333333333,
#   u'pain': 0.3333333333333333,
#   u'pc': 0.3333333333333333},
#  (u'to', u'was'): {u'do': 0.5, u'me': 0.5},
#  (u'i', u'clean'): {u'just': 0.5, u'usually': 0.5},
#  (u'.', u'friend'): {u'a': 0.5, u'my': 0.5},
#  (u'want', u'.'): {u')': 0.5, u'it': 0.5},
#  (u'it', u'fit'): {u'did': 0.3333333333333333,
#   u'to': 0.3333333333333333,
#   u'will': 0.3333333333333333},
#  (u'the', u'i'): {u'6000.': 0.014705882352941176,
#   u'abuse': 0.014705882352941176,
#   u'application': 0.014705882352941176,
#   u'batteries': 0.014705882352941176,
#   u'best': 0.07352941176470588,
#   u'box': 0.014705882352941176,
#   u'brand': 0.014705882352941176,
#   u'bridge': 0.014705882352941176,
#   u'cables': 0.014705882352941176,
#   u'car': 0.029411764705882353,
#   u'case': 0.014705882352941176,
#   u'closest': 0.014705882352941176,
#   u'conclusion': 0.014705882352941176,
#   u'cord': 0.014705882352941176,
#   u'couple': 0.014705882352941176,
#   u'earphones': 0.014705882352941176,
#   u'end': 0.014705882352941176,
#   u'fact': 0.029411764705882353,
#   u'fans': 0.014705882352941176,
#   u'first': 0.014705882352941176,
#   u'games': 0.014705882352941176,
#   u'ipod': 0.014705882352941176,
#   u'item': 0.014705882352941176,
#   u'items': 0.014705882352941176,
#   u'longest': 0.014705882352941176,
#   u'menus': 0.014705882352941176,
#   u'minute': 0.014705882352941176,
#   u'modem': 0.014705882352941176,
#   u'moment': 0.014705882352941176,
#   u'name': 0.014705882352941176,
#   u'one': 0.029411764705882353,
#   u'ones': 0.014705882352941176,
#   u'package': 0.014705882352941176,
#   u'pain': 0.014705882352941176,
#   u'part': 0.029411764705882353,
#   u'phone': 0.014705882352941176,
#   u'price': 0.058823529411764705,
#   u'product': 0.04411764705882353,
#   u'qualities': 0.014705882352941176,
#   u'reason': 0.07352941176470588,
#   u'reviews': 0.029411764705882353,
#   u'route': 0.014705882352941176,
#   u'songs': 0.029411764705882353,
#   u'stores': 0.014705882352941176,
#   u'things': 0.014705882352941176,
#   u'time': 0.014705882352941176,
#   u'times': 0.014705882352941176,
#   u'unit': 0.014705882352941176,
#   u'volume': 0.014705882352941176},
#  (u'it', u'did'): {u'certainly': 0.3333333333333333,
#   u'ever': 0.3333333333333333,
#   u'just': 0.3333333333333333},
#  (u'was', u','): {u'amazed': 0.0625,
#   u'because': 0.0625,
#   u'cheaper': 0.0625,
#   u'downloaded': 0.0625,
#   u'fine': 0.0625,
#   u'great': 0.0625,
#   u'hard': 0.0625,
#   u'in': 0.0625,
#   u'outrageous': 0.0625,
#   u'perfect': 0.0625,
#   u'poor': 0.125,
#   u'small': 0.0625,
#   u'so': 0.0625,
#   u'weary': 0.0625,
#   u'wonky': 0.0625},
#  (u'a', u'because'): {u'desk': 0.5, u'nightmare': 0.5},
#  (u'had', u'much'): {u'a': 0.5, u'too': 0.5},
#  (u'and', u'loved'): {u'i': 0.5, u'we': 0.5},
#  (u'hard', u'to'): {u'pressed': 0.5, u'pressesd': 0.5},
#  (u'well', u'it'): {u',': 0.18181818181818182,
#   u'.': 0.2727272727272727,
#   u'as': 0.09090909090909091,
#   u'but': 0.09090909090909091,
#   u'supported': 0.09090909090909091,
#   u'until': 0.09090909090909091,
#   u'with': 0.09090909090909091,
#   u'worth': 0.09090909090909091},
#  (u'very', u'at'): {u'good': 0.5, u'pleased': 0.5},
#  (u'entire', u'to'): {u'collection': 0.3333333333333333,
#   u'list': 0.3333333333333333,
#   u'system': 0.3333333333333333},
#  (u'over', u'years'): {u'10': 0.16666666666666666,
#   u'2': 0.08333333333333333,
#   u'20': 0.08333333333333333,
#   u'7': 0.16666666666666666,
#   u'five': 0.08333333333333333,
#   u'the': 0.16666666666666666,
#   u'three': 0.08333333333333333,
#   u'two': 0.16666666666666666},
#  (u'been', u'.'): {u'cheaper': 0.1,
#   u'correct': 0.1,
#   u'excellent': 0.1,
#   u'fine': 0.1,
#   u'high': 0.1,
#   u'marginal': 0.1,
#   u'opened': 0.1,
#   u'printed': 0.1,
#   u'resolved': 0.1,
#   u'terrific': 0.1},
#  (u'2', u'per'): {u'%': 0.3333333333333333, u'cents': 0.6666666666666666},
#  (u'are', u'few'): {u'a': 0.8333333333333334, u'very': 0.16666666666666666},
#  (u'finally', u'on'): {u'decided': 0.4, u'jumped': 0.2, u'settled': 0.4},
#  (u"n't", u'to'): {u'allowed': 0.019230769230769232,
#   u'attest': 0.019230769230769232,
#   u'bear': 0.019230769230769232,
#   u'decide': 0.019230769230769232,
#   u'forget': 0.038461538461538464,
#   u'going': 0.057692307692307696,
#   u'had': 0.019230769230769232,
#   u'have': 0.23076923076923078,
#   u'hesitate': 0.038461538461538464,
#   u'likely': 0.019230769230769232,
#   u'listem': 0.019230769230769232,
#   u'listen': 0.019230769230769232,
#   u'need': 0.057692307692307696,
#   u'pretend': 0.019230769230769232,
#   u'seem': 0.11538461538461539,
#   u'speak': 0.019230769230769232,
#   u'tend': 0.019230769230769232,
#   u'wait': 0.038461538461538464,
#   u'want': 0.21153846153846154},
#  (u'do', u'as'): {u'.': 0.5, u'so': 0.5},
#  (u'.', u'buy'): {u'best': 0.25, u'good': 0.25, u'i': 0.25, u'would': 0.25},
#  (u'the', u'play'): {u'``': 0.5, u'random': 0.5},
#  (u'unlock', u'that'): {u'code': 0.5, u'on': 0.5},
#  (u'...', u'suddenly'): {u'.': 0.5, u'and': 0.5},
#  (u'a', u'volume'): {u'dedicated': 0.16666666666666666,
#   u'good': 0.16666666666666666,
#   u'higher': 0.16666666666666666,
#   u'low': 0.16666666666666666,
#   u'lower': 0.16666666666666666,
#   u'wide': 0.16666666666666666},
#  (u"'ll", u'have'): {u'either': 0.5, u'never': 0.5},
#  (u'for', u'where'): {u'areas': 0.5, u'music': 0.5},
#  (u'someone', u'to'): {u'forgot': 0.3333333333333333,
#   u'looking': 0.3333333333333333,
#   u'next': 0.3333333333333333},
#  (u')', u'while'): {u',': 0.5, u'and': 0.5},
#  (u'much', u'as'): {u'bass': 0.3333333333333333,
#   u'money': 0.3333333333333333,
#   u'useless': 0.3333333333333333},
#  (u'-', u'design'): {u'nice': 0.5, u'simple': 0.5},
#  (u'dots', u'the'): {u'of': 0.5, u'on': 0.5},
#  (u',', u'went'): {u'everything': 0.3333333333333333,
#   u'i': 0.6666666666666666},
#  (u'fm', u'and'): {u'antenna': 0.2, u'radio': 0.2, u'transmitter': 0.6},
#  (u'a', u'storage'): {u'great': 0.5, u'small': 0.5},
#  (u'case', u"n't"): {u'did': 0.5, u'wo': 0.5},
#  (u'--', u'was'): {u'it': 0.5, u'this': 0.5},
#  (u'because', u'will'): {u'headphones': 0.5, u'you': 0.5},
#  (u'normally', u'the'): {u'.': 0.5, u'use': 0.5},
#  (u'.', u'monitor'): {u'the': 0.3333333333333333, u'this': 0.6666666666666666},
#  (u'money', u'it'): {u',': 0.75, u'.': 0.25},
#  (u'on', u'router'): {u'my': 0.5, u'your': 0.5},
#  (u'of', u'having'): {u'amazon': 0.5, u'not': 0.5},
#  (u'card', u'i'): {u',': 0.2857142857142857,
#   u'.': 0.5714285714285714,
#   u'so': 0.14285714285714285},
#  (u'.', u'is'): {u'amazon': 0.005025125628140704,
#   u'bass': 0.005025125628140704,
#   u'brightness': 0.005025125628140704,
#   u'ca-706': 0.005025125628140704,
#   u'd-pad': 0.005025125628140704,
#   u'digital': 0.005025125628140704,
#   u'editing': 0.005025125628140704,
#   u'everything': 0.01507537688442211,
#   u'he': 0.005025125628140704,
#   u'here': 0.020100502512562814,
#   u'installation': 0.005025125628140704,
#   u'isolation': 0.005025125628140704,
#   u'it': 0.38190954773869346,
#   u'life': 0.005025125628140704,
#   u'memory': 0.005025125628140704,
#   u'midrange': 0.005025125628140704,
#   u'mine': 0.005025125628140704,
#   u'mouse': 0.005025125628140704,
#   u'padding': 0.005025125628140704,
#   u'picture': 0.005025125628140704,
#   u'polk': 0.005025125628140704,
#   u'portability': 0.005025125628140704,
#   u'problem': 0.005025125628140704,
#   u'resolution': 0.005025125628140704,
#   u'sandisk': 0.005025125628140704,
#   u'scanning': 0.005025125628140704,
#   u'she': 0.005025125628140704,
#   u'sound': 0.020100502512562814,
#   u'subwoofer': 0.005025125628140704,
#   u'such': 0.005025125628140704,
#   u'text': 0.005025125628140704,
#   u'that': 0.04522613065326633,
#   u'there': 0.12060301507537688,
#   u'this': 0.21105527638190955,
#   u'tracking': 0.005025125628140704,
#   u'treble': 0.005025125628140704,
#   u'vinyl': 0.005025125628140704,
#   u'volume': 0.005025125628140704,
#   u'warranty': 0.010050251256281407,
#   u'what': 0.010050251256281407,
#   u'which': 0.005025125628140704,
#   u'wifi': 0.005025125628140704},
#  (u'and', u'well'): {u'go': 0.2,
#   u'perform': 0.2,
#   u'syncs': 0.2,
#   u'works': 0.4},
#  (u';', u')'): {u'-': 0.5, u'2': 0.25, u'3': 0.25},
#  (u'as', u'does'): {u'anyone': 0.5, u'it': 0.5},
#  (u'buttons', u'.'): {u'do': 0.5, u'though': 0.5},
#  (u'tape', u'.'): {u'deck': 0.3333333333333333,
#   u'players': 0.3333333333333333,
#   u'units': 0.3333333333333333},
#  (u'there', u'some'): {u'are': 0.2, u'is': 0.4, u'were': 0.4},
#  (u'but', u'wo'): {u'it': 0.6666666666666666, u'we': 0.3333333333333333},
#  (u'fact', u'it'): {u',': 0.375, u'that': 0.625},
#  (u'which', u'every'): {u'checks': 0.5, u'covers': 0.5},
#  (u'to', u'these'): {u'buy': 0.16666666666666666,
#   u'game': 0.08333333333333333,
#   u'get': 0.08333333333333333,
#   u'give': 0.08333333333333333,
#   u'hold': 0.08333333333333333,
#   u'keep': 0.08333333333333333,
#   u'make': 0.08333333333333333,
#   u'manufacturing': 0.08333333333333333,
#   u'send': 0.08333333333333333,
#   u'store': 0.08333333333333333,
#   u'use': 0.08333333333333333},
#  (u'.', u'obvious'): {u'no': 0.5, u'the': 0.5},
#  (u'that', u'my'): {u'.': 0.2,
#   u'built': 0.2,
#   u'holds': 0.2,
#   u'makes': 0.2,
#   u'with': 0.2},
#  (u'case', u'like'): {u'.': 0.5, u'seems': 0.5},
#  (u'high', u'.'): {u'definition': 0.1111111111111111,
#   u'end': 0.1111111111111111,
#   u'expectations': 0.1111111111111111,
#   u'frequencies': 0.1111111111111111,
#   u'levels': 0.1111111111111111,
#   u'quality': 0.3333333333333333,
#   u'volumes': 0.1111111111111111},
#  (u'that', u'never'): {u'i': 0.6, u'it': 0.2, u'were': 0.2},
#  (u'of', u'around'): {u'playing': 0.5, u'trees': 0.5},
#  (u'a', u'was'): {u'driver': 0.3333333333333333,
#   u'replacement': 0.3333333333333333,
#   u'song': 0.3333333333333333},
#  (u'best', u'phones'): {u'budget': 0.5, u'wireless': 0.5},
#  (u'best', u'i'): {u'.': 0.18181818181818182,
#   u'5.8': 0.045454545454545456,
#   u'accuracy': 0.045454545454545456,
#   u'bag': 0.045454545454545456,
#   u'buy': 0.045454545454545456,
#   u'device': 0.045454545454545456,
#   u'earphones': 0.045454545454545456,
#   u'gadget-products': 0.045454545454545456,
#   u'headphones': 0.09090909090909091,
#   u'mic': 0.045454545454545456,
#   u'mouse': 0.13636363636363635,
#   u'phones': 0.045454545454545456,
#   u'product': 0.045454545454545456,
#   u'purchase': 0.045454545454545456,
#   u'speakers': 0.045454545454545456,
#   u'webcam': 0.045454545454545456},
#  (u'the', u'wireless'): {u'best': 0.16666666666666666,
#   u'dual-band': 0.16666666666666666,
#   u'logitech': 0.16666666666666666,
#   u'microsoft': 0.16666666666666666,
#   u'old': 0.16666666666666666,
#   u'totally': 0.16666666666666666},
#  (u'now', u'use'): {u'and': 0.5, u'only': 0.5},
#  (u'first', u'is'): {u',': 0.2, u'name': 0.2, u'one': 0.4, u'x50': 0.2},
#  (u'bluetooth', u'to'): {u'headset': 0.5, u'through': 0.5},
#  (u'has', u'on'): {u'crashed': 0.5, u'instructions': 0.5},
#  (u'analog', u'.'): {u'inputs': 0.5, u'knob': 0.5},
#  (u'problem', u'you'): {u'for': 0.5, u'if': 0.5},
#  (u'tv', u'a'): {u'has': 0.5, u'weighs': 0.5},
#  (u"n't", u'why'): {u'get': 0.2, u'know': 0.6, u'understand': 0.2},
#  (u'range', u'the'): {u'and': 0.3333333333333333,
#   u'of': 0.16666666666666666,
#   u'on': 0.16666666666666666,
#   u'to': 0.16666666666666666,
#   u'without': 0.16666666666666666},
#  (u"n't", u'quite'): {u'feel': 0.16666666666666666,
#   u'has': 0.16666666666666666,
#   u'need': 0.16666666666666666,
#   u'seem': 0.16666666666666666,
#   u'work': 0.3333333333333333},
#  (u'it', u'into'): {u'right': 0.5, u'slides': 0.5},
#  (u'has', u'good'): {u'been': 0.5, u'very': 0.5},
#  (u'it', u'because'): {u"'s": 0.16666666666666666,
#   u',': 0.3333333333333333,
#   u'completely': 0.16666666666666666,
#   u'primarily': 0.16666666666666666,
#   u'should': 0.16666666666666666},
#  (u'a', u'less'): {u'little': 0.75, u'lot': 0.25},
#  (u'i', u'glad'): {u"'m": 0.7, u'am': 0.3},
#  (u'i', u'i'): {u'admit': 0.041666666666666664,
#   u'decided': 0.041666666666666664,
#   u'did': 0.041666666666666664,
#   u'feel': 0.08333333333333333,
#   u'figured': 0.08333333333333333,
#   u'find': 0.041666666666666664,
#   u'forget': 0.041666666666666664,
#   u'forgot': 0.041666666666666664,
#   u'knew': 0.041666666666666664,
#   u'mean': 0.041666666666666664,
#   u'ordered': 0.041666666666666664,
#   u'paid': 0.041666666666666664,
#   u'realized': 0.041666666666666664,
#   u'sit': 0.041666666666666664,
#   u'swear': 0.041666666666666664,
#   u'think': 0.125,
#   u'thought': 0.16666666666666666},
#  (u'5', u'for'): {u'adapters': 0.25,
#   u'inks': 0.25,
#   u'minutes': 0.25,
#   u'stars': 0.25},
#  (u'one', u"'s"): {u'that': 0.5, u'thing': 0.5},
#  (u'3', u','): {u'handsets': 0.3333333333333333,
#   u'months': 0.3333333333333333,
#   u'presets': 0.3333333333333333},
#  (u'case', u'a'): {u'and': 0.25, u'for': 0.25, u'is': 0.25, u'with': 0.25},
#  (u'of', u'these'): {u'all': 0.6666666666666666,
#   u'keeping': 0.3333333333333333},
#  (u'the', u'except'): {u'case': 0.5, u'ipod': 0.5},
#  (u'without', u'a'): {u'needing': 0.3333333333333333,
#   u'running': 0.3333333333333333,
#   u'using': 0.3333333333333333},
#  (u'made', u'the'): {u'before': 0.25, u'into': 0.5, u'off': 0.25},
#  (u'5', u"'s"): {u'eb': 0.5, u'stars..it': 0.5},
#  (u'and', u'versa'): {u'vice': 0.6666666666666666,
#   u'vise': 0.3333333333333333},
#  (u'my', u'if'): {u'chest': 0.5, u'route': 0.5},
#  (u'that', u'and'): {u'class': 0.2,
#   u'good': 0.2,
#   u'holds': 0.2,
#   u'motor': 0.2,
#   u'nite': 0.2},
#  (u'on', u'list'): {u'my': 0.25, u'the': 0.75},
#  (u'when', u'the'): {u'facing': 0.14285714285714285,
#   u'hearing': 0.14285714285714285,
#   u'playing': 0.14285714285714285,
#   u'slung': 0.14285714285714285,
#   u'using': 0.42857142857142855},
#  (u'this', u'more'): {u'gets': 0.3333333333333333, u'is': 0.6666666666666666},
#  (u'geforce', u'pci'): {u'6600': 0.5, u'7800gt': 0.5},
#  (u"n't", u'easy'): {u'always': 0.5, u'that': 0.5},
#  (u'i', u'thinking'): {u'kept': 0.5, u'was': 0.5},
#  (u"'ve", u'gotten'): {u'both': 0.5, u'never': 0.5},
#  (u',', u'price'): {u'good': 0.14285714285714285,
#   u'gret': 0.14285714285714285,
#   u'right': 0.14285714285714285,
#   u'the': 0.5714285714285714},
#  (u'.', u'gets'): {u'it': 0.6666666666666666, u'this': 0.3333333333333333},
#  (u'tunes', u'i'): {u'.': 0.5, u'that': 0.5},
#  (u'premium', u'('): {u'device': 0.5, u'price': 0.5},
#  (u'photo', u'.'): {u'printing': 0.5, u'shop': 0.5},
#  (u'(', u'or'): {u'802.11b': 0.16666666666666666,
#   u'blue': 0.16666666666666666,
#   u'closet': 0.16666666666666666,
#   u'ii': 0.16666666666666666,
#   u'optical': 0.16666666666666666,
#   u'wireless': 0.16666666666666666},
#  (u'for', u'use'): {u'car': 0.125,
#   u'everyday': 0.125,
#   u'home': 0.25,
#   u'most': 0.125,
#   u'my': 0.125,
#   u'office': 0.125,
#   u'personal': 0.125},
#  (u'document', u','): {u'feeder': 0.5, u'load': 0.5},
#  (u'nice', u'and'): {u'bag': 0.25,
#   u'display': 0.25,
#   u'feature': 0.25,
#   u'looking': 0.25},
#  (u'work', u'other'): {u'.': 0.5, u'in': 0.5},
#  (u'hard', u','): {u'case': 0.2, u'drive': 0.4, u'rock': 0.2, u'surface': 0.2},
#  (u'(', u','): {u'granted': 0.1111111111111111,
#   u'ie': 0.05555555555555555,
#   u'kodak': 0.05555555555555555,
#   u'mesa': 0.05555555555555555,
#   u'music': 0.05555555555555555,
#   u'odd': 0.05555555555555555,
#   u'one-handed': 0.05555555555555555,
#   u'plasma': 0.05555555555555555,
#   u'power': 0.05555555555555555,
#   u'remember': 0.05555555555555555,
#   u'samsung': 0.05555555555555555,
#   u'though': 0.05555555555555555,
#   u'umbrella': 0.05555555555555555,
#   u'v1.0': 0.05555555555555555,
#   u'well': 0.05555555555555555,
#   u'which': 0.05555555555555555,
#   u'white': 0.05555555555555555},
#  (u'first', u'this'): {u',': 0.16666666666666666,
#   u'.': 0.16666666666666666,
#   u'heard': 0.16666666666666666,
#   u'if': 0.16666666666666666,
#   u'installed': 0.16666666666666666,
#   u'purchased': 0.16666666666666666},
#  (u'most', u'keyboards'): {u'comfortable': 0.5, u'cordless': 0.5},
#  (u'the', u'all'): {u'bass': 0.2,
#   u'brightness': 0.2,
#   u'charger': 0.2,
#   u'headband': 0.2,
#   u'viewer': 0.2},
#  (u'(', u'is'): {u'48gx': 0.07142857142857142,
#   u'hd': 0.07142857142857142,
#   u'that': 0.21428571428571427,
#   u'there': 0.07142857142857142,
#   u'this': 0.21428571428571427,
#   u'which': 0.35714285714285715},
#  (u'a', u'larger'): {u'bit': 0.5, u'much': 0.5},
#  (u'to', u'using'): {u'arrive': 0.25,
#   u'be': 0.25,
#   u'it': 0.25,
#   u'start': 0.25},
#  (u'did', u'like'): {u"n't": 0.7777777777777778, u'not': 0.2222222222222222},
#  (u'maps', u'the'): {u'for': 0.6666666666666666, u'or': 0.3333333333333333},
#  (u'off', u'and'): {u'(': 0.5, u')': 0.5},
#  (u'price', u'if'): {u')': 0.25, u'.': 0.75},
#  (u'when', u'walk'): {u'i': 0.5, u'you': 0.5},
#  (u'would', u'that'): {u'be': 0.4, u'guess': 0.2, u'say': 0.2, u'think': 0.2},
#  (u'in', u'than'): {u'better': 0.3333333333333333,
#   u'less': 0.3333333333333333,
#   u'person': 0.3333333333333333},
#  (u'it', u'seem'): {u'may': 0.3333333333333333,
#   u'might': 0.3333333333333333,
#   u'would': 0.3333333333333333},
#  (u'ipod', u'please'): {u',': 0.5, u'.': 0.5},
#  (u'player', u'radio'): {u',': 0.5, u'into.xm': 0.5},
#  (u'has', u','): {u'component': 0.16666666666666666,
#   u'dvi': 0.16666666666666666,
#   u'music': 0.16666666666666666,
#   u'radio': 0.3333333333333333,
#   u'this': 0.16666666666666666},
#  (u'they', u'awesome'): {u'sound': 0.5, u'sounded': 0.5},
#  (u'$', u'total'): {u'16': 0.3333333333333333,
#   u'650.00': 0.3333333333333333,
#   u'750': 0.3333333333333333},
#  (u'my', u';'): {u'non-drm': 0.5, u'travels': 0.5},
#  (u'in', u'regard'): {u'that': 0.4, u'this': 0.6},
#  (u'speakers', u'their'): {u'.': 0.5, u'for': 0.5},
#  (u'but', u'were'): {u'there': 0.3333333333333333,
#   u'they': 0.6666666666666666},
#  (u'but', u'unit'): {u'the': 0.5, u'this': 0.5},
#  (u'use', u'every'): {u'it': 0.5, u'them': 0.5},
#  (u'stereo', u','): {u'replacement': 0.25, u'sound': 0.25, u'system': 0.5},
#  (u'i', u'these'): {u'berate': 0.024390243902439025,
#   u'blame': 0.024390243902439025,
#   u'bought': 0.2926829268292683,
#   u'burn': 0.024390243902439025,
#   u'chose': 0.024390243902439025,
#   u'got': 0.04878048780487805,
#   u'had': 0.024390243902439025,
#   u'have': 0.024390243902439025,
#   u'heard': 0.024390243902439025,
#   u'liked': 0.024390243902439025,
#   u'love': 0.07317073170731707,
#   u'ordered': 0.024390243902439025,
#   u'plugged': 0.024390243902439025,
#   u'prefer': 0.024390243902439025,
#   u'purchased': 0.024390243902439025,
#   u'received': 0.024390243902439025,
#   u'recommend': 0.024390243902439025,
#   u'tested': 0.024390243902439025,
#   u'think': 0.04878048780487805,
#   u'tried': 0.024390243902439025,
#   u'underestimated': 0.024390243902439025,
#   u'use': 0.07317073170731707,
#   u'used': 0.024390243902439025,
#   u'wish': 0.024390243902439025},
#  (u'excellent', u'and'): {u'bass': 0.14285714285714285,
#   u'buy': 0.14285714285714285,
#   u'construction': 0.14285714285714285,
#   u'detail': 0.14285714285714285,
#   u'price': 0.14285714285714285,
#   u'shape': 0.14285714285714285,
#   u'sound': 0.14285714285714285},
#  (u'of', u"'s"): {u'brian': 0.058823529411764705,
#   u'canon': 0.058823529411764705,
#   u'cd': 0.058823529411764705,
#   u'cd-r': 0.058823529411764705,
#   u'd-link': 0.058823529411764705,
#   u'day': 0.058823529411764705,
#   u'it': 0.47058823529411764,
#   u'kodak': 0.058823529411764705,
#   u'today': 0.058823529411764705,
#   u'vivaldi': 0.058823529411764705},
#  (u'i', u'with'): {u'agree': 0.16666666666666666,
#   u'connect': 0.05555555555555555,
#   u'found': 0.05555555555555555,
#   u'have': 0.16666666666666666,
#   u'produced': 0.05555555555555555,
#   u'started': 0.1111111111111111,
#   u'talk': 0.05555555555555555,
#   u'use': 0.05555555555555555,
#   u'walk': 0.05555555555555555,
#   u'went': 0.2222222222222222},
#  (u'have', u'gps'): {u'the': 0.5, u'used': 0.5},
#  (u'.', u'best'): {u'for': 0.1111111111111111, u'the': 0.8888888888888888},
#  (u'get', u'right'): {u'going': 0.5, u'the': 0.5},
#  (u'most', u'part'): {u'annoying': 0.3333333333333333,
#   u'subjective': 0.3333333333333333,
#   u'unique': 0.3333333333333333},
#  (u'this', u'two'): {u'for': 0.5, u'operation': 0.5},
#  (u'you', u'then'): {u',': 0.3333333333333333,
#   u'are': 0.3333333333333333,
#   u'save': 0.3333333333333333},
#  (u'to', u'left'): {u'lean': 0.3333333333333333,
#   u'my': 0.3333333333333333,
#   u'your': 0.3333333333333333},
#  (u'that', u'was'): {u'brian': 0.1,
#   u'i': 0.1,
#   u'it': 0.4,
#   u'madrid': 0.1,
#   u'microsoft': 0.1,
#   u'there': 0.1,
#   u'this': 0.1},
#  (u'connection', u'i'): {u',': 0.25, u'.': 0.25, u'but': 0.25, u'so': 0.25},
#  (u'the', u'about'): {u'battery': 0.2,
#   u'concern': 0.2,
#   u'negativity': 0.2,
#   u'rumor': 0.2,
#   u'street': 0.2},
#  (u'phone', u'an'): {u'from': 0.5, u'was': 0.5},
#  (u'installation', u'simple'): {u'is': 0.5, u'was': 0.5},
#  (u'no', u'setting'): {u'difficulty': 0.5, u'problems': 0.5},
#  (u'my', u'impression'): {u'first': 0.5, u'quick': 0.5},
#  (u'is', u'they'): {u'because': 0.1111111111111111,
#   u'that': 0.7777777777777778,
#   u'why': 0.1111111111111111},
#  (u'still', u'a'): {u'got': 0.25,
#   u'have': 0.25,
#   u'having': 0.25,
#   u'not': 0.25},
#  (u'cable', u'('): {u'.': 0.3333333333333333,
#   u'modem': 0.3333333333333333,
#   u'provider': 0.3333333333333333},
#  (u'for', u'hp'): {u'her': 0.3333333333333333,
#   u'my': 0.3333333333333333,
#   u'your': 0.3333333333333333},
#  (u'or', u'at'): {u'look': 0.5, u'picture': 0.25, u'whatever': 0.25},
#  (u'get', u'new'): {u'a': 0.6, u'my': 0.2, u'the': 0.2},
#  (u'of', u'player'): {u'date': 0.3333333333333333, u'the': 0.6666666666666666},
#  (u'(', u'from'): {u'like': 0.5, u'purchased': 0.5},
#  (u'worked', u'well'): {u'quite': 0.25, u'verry': 0.25, u'very': 0.5},
#  (u'design', u'works'): {u',': 0.5, u'and': 0.5},
#  (u'have', u'complaints'): {u'any': 0.14285714285714285,
#   u'heard': 0.14285714285714285,
#   u'no': 0.7142857142857143},
#  (u'it', u'excellent'): {u"'s": 0.3333333333333333,
#   u'has': 0.3333333333333333,
#   u'is': 0.3333333333333333},
#  (u'the', u'product'): {u'best': 0.2222222222222222,
#   u'covered': 0.2222222222222222,
#   u'hd': 0.1111111111111111,
#   u'nulooq': 0.1111111111111111,
#   u'perfect': 0.1111111111111111,
#   u'portable': 0.1111111111111111,
#   u'same': 0.1111111111111111},
#  (u'second', u'that'): {u'color': 0.5, u'one': 0.5},
#  (u'recommend', u'.'): {u'it': 0.5, u'them': 0.5},
#  (u'it', u'makes'): {u'also': 0.5, u'really': 0.5},
#  (u'data', u'and'): {u'back': 0.5, u'fast': 0.5},
#  (u'the', u'&'): {u'+': 0.14285714285714285,
#   u'er4p': 0.14285714285714285,
#   u'mount': 0.14285714285714285,
#   u'pouch': 0.14285714285714285,
#   u'rack': 0.14285714285714285,
#   u'senators': 0.14285714285714285,
#   u'up': 0.14285714285714285},
#  (u',', u'connect'): {u'and': 0.5, u'just': 0.5},
#  (u'iem', u','): {u"'s": 0.5, u'headphones': 0.5},
#  (u'i', u'press'): {u'can': 0.5, u'do': 0.5},
#  (u'anyone', u'is'): {u'that': 0.3333333333333333, u'who': 0.6666666666666666},
#  (u'cd', u'is'): {u'holder': 0.3333333333333333,
#   u'import': 0.3333333333333333,
#   u'sound': 0.3333333333333333},
#  (u'with', u'dvd+r'): {u'fujifilm': 0.5, u'tdk': 0.5},
#  (u'.', u'verbatim'): {u'the': 0.5, u'these': 0.5},
#  (u'of', u'who'): {u'mine': 0.125, u'us': 0.125, u'you': 0.75},
#  (u'the', u'headphones'): {u'best': 0.6666666666666666,
#   u'h250': 0.3333333333333333},
#  (u'reviews', u'here'): {u'(': 0.5, u'on': 0.5},
#  (u'tape', u'the'): {u'on': 0.5, u'over': 0.5},
#  (u'your', u'camera'): {u'digital': 0.6666666666666666,
#   u'specific': 0.3333333333333333},
#  (u'the', u'plugs'): {u'ear': 0.3333333333333333,
#   u'mini': 0.16666666666666666,
#   u'receiver': 0.16666666666666666,
#   u'red-and-white': 0.16666666666666666,
#   u'twin': 0.16666666666666666},
#  (u'4:3', u'wide'): {u'and': 0.5, u'or': 0.5},
#  (u'screen', u'.'): {u')': 0.2,
#   u'protection': 0.2,
#   u'real-estate': 0.2,
#   u'replaced': 0.2,
#   u'tv': 0.2},
#  (u'similar', u'.'): {u'alternatives': 0.5, u'type': 0.5},
#  (u'and', u"''"): {u'.75': 0.2,
#   u'15': 0.2,
#   u'20': 0.2,
#   u'30': 0.2,
#   u'all': 0.2},
#  (u'everything', u'the'): {u'.': 0.5, u'in': 0.5},
#  (u'the', u'much'): {u'are': 0.2,
#   u'camera': 0.2,
#   u'eq': 0.2,
#   u'position': 0.2,
#   u'screen': 0.2},
#  (u'good', u'small'): {u',': 0.5, u'for': 0.5},
#  (u'at', u'.'): {u'4x': 0.02631578947368421,
#   u'all': 0.5,
#   u'amazon': 0.02631578947368421,
#   u'apc': 0.02631578947368421,
#   u'first': 0.02631578947368421,
#   u'home': 0.07894736842105263,
#   u'it': 0.02631578947368421,
#   u'most': 0.02631578947368421,
#   u'night': 0.05263157894736842,
#   u'once': 0.07894736842105263,
#   u'that': 0.02631578947368421,
#   u'times': 0.05263157894736842,
#   u'u3.com': 0.02631578947368421,
#   u'work': 0.02631578947368421},
#  (u'space', u'and'): {u')': 0.3333333333333333,
#   u',': 0.3333333333333333,
#   u'.': 0.3333333333333333},
#  (u'on', u'mouse'): {u'the': 0.6666666666666666, u'this': 0.3333333333333333},
#  (u'but', u'like'): {u'functions': 0.3333333333333333,
#   u'i': 0.6666666666666666},
#  (u'of', u'i'): {u'.': 0.07142857142857142,
#   u'all': 0.07142857142857142,
#   u'benefits': 0.07142857142857142,
#   u'buds': 0.07142857142857142,
#   u'course': 0.07142857142857142,
#   u'it': 0.07142857142857142,
#   u'junk': 0.07142857142857142,
#   u'months': 0.07142857142857142,
#   u'mouse': 0.07142857142857142,
#   u'this': 0.07142857142857142,
#   u'trepidation': 0.07142857142857142,
#   u'volume': 0.07142857142857142,
#   u'where': 0.07142857142857142,
#   u'which': 0.07142857142857142},
#  (u'.', u'first'): {u'at': 0.10526315789473684,
#   u'for': 0.05263157894736842,
#   u'i': 0.15789473684210525,
#   u'my': 0.10526315789473684,
#   u'the': 0.5263157894736842,
#   u'well': 0.05263157894736842},
#  (u'bass', u'a'): {u'in': 0.25, u'is': 0.5, u'slider': 0.25},
#  (u'the', u'point'): {u'price': 0.25,
#   u'selling': 0.25,
#   u'thickest': 0.25,
#   u'widest': 0.25},
#  (u'got', u'i'): {u'this': 0.5, u'what': 0.5},
#  (u')', u'the'): {u'!': 0.0196078431372549,
#   u',': 0.0784313725490196,
#   u'.': 0.43137254901960786,
#   u'and': 0.1568627450980392,
#   u'at': 0.0196078431372549,
#   u'because': 0.0196078431372549,
#   u'but': 0.0196078431372549,
#   u'for': 0.0784313725490196,
#   u'from': 0.0196078431372549,
#   u'on': 0.0392156862745098,
#   u'press': 0.0196078431372549,
#   u'reads': 0.0196078431372549,
#   u'stretch': 0.0196078431372549,
#   u'that': 0.0196078431372549,
#   u'when': 0.0196078431372549,
#   u'whereas': 0.0196078431372549},
#  (u'minor', u'for'): {u'annoyance': 0.5, u'sacrifice': 0.5},
#  (u'cables', u'are'): {u'produce': 0.25, u'that': 0.25, u'themselves': 0.5},
#  (u'out', u'as'): {u'.': 0.6666666666666666, u'just': 0.3333333333333333},
#  (u'recorded', u','): {u'again': 0.5, u'albums': 0.5},
#  (u'.', u'a'): {u'adding': 0.02127659574468085,
#   u'after': 0.02127659574468085,
#   u'as': 0.10638297872340426,
#   u'at': 0.0425531914893617,
#   u'being': 0.02127659574468085,
#   u'certainly': 0.02127659574468085,
#   u'connected': 0.02127659574468085,
#   u'definitely': 0.02127659574468085,
#   u'for': 0.02127659574468085,
#   u'generally': 0.02127659574468085,
#   u'got': 0.02127659574468085,
#   u'had': 0.02127659574468085,
#   u'having': 0.02127659574468085,
#   u'if': 0.0425531914893617,
#   u'im': 0.02127659574468085,
#   u'in': 0.0425531914893617,
#   u'installing': 0.02127659574468085,
#   u'is': 0.02127659574468085,
#   u'its': 0.0425531914893617,
#   u'just': 0.0425531914893617,
#   u'never': 0.02127659574468085,
#   u'not': 0.06382978723404255,
#   u'on': 0.02127659574468085,
#   u'overall': 0.0425531914893617,
#   u'playing': 0.02127659574468085,
#   u'since': 0.02127659574468085,
#   u'thanks': 0.02127659574468085,
#   u'until': 0.02127659574468085,
#   u'used': 0.02127659574468085,
#   u'what': 0.0425531914893617,
#   u'when': 0.02127659574468085,
#   u'with': 0.02127659574468085,
#   u'within': 0.02127659574468085,
#   u'without': 0.02127659574468085},
#  (u'at', u'good'): {u'a': 0.5, u'how': 0.5},
#  (u'them', u'and'): {u'(': 0.09090909090909091,
#   u',': 0.45454545454545453,
#   u'around': 0.09090909090909091,
#   u'back': 0.09090909090909091,
#   u'both': 0.09090909090909091,
#   u'in': 0.09090909090909091,
#   u'new': 0.09090909090909091},
#  (u'one', u'i'): {u'.': 0.42857142857142855,
#   u'and': 0.047619047619047616,
#   u'died': 0.047619047619047616,
#   u'problem': 0.09523809523809523,
#   u'reason': 0.047619047619047616,
#   u'that': 0.14285714285714285,
#   u'thing': 0.047619047619047616,
#   u'time': 0.047619047619047616,
#   u'when': 0.09523809523809523},
#  (u'actually', u'the'): {u'distorts': 0.16666666666666666,
#   u'had': 0.16666666666666666,
#   u'not': 0.16666666666666666,
#   u'reduces': 0.16666666666666666,
#   u'replaced': 0.16666666666666666,
#   u'shows': 0.16666666666666666},
#  (u'does', u'support'): {u"n't": 0.75, u'not': 0.25},
#  (u'have', u'sensitivity'): {u'low': 0.5, u'poor': 0.5},
#  (u'old', u'.'): {u'one': 0.2857142857142857,
#   u'ones': 0.14285714285714285,
#   u'radio': 0.14285714285714285,
#   u'sandisk': 0.14285714285714285,
#   u'son': 0.14285714285714285,
#   u'system': 0.14285714285714285},
#  (u'connection', u'a'): {u'and': 0.5, u'to': 0.5},
#  (u'.', u'alone'): {u'simcity': 0.5, u'that': 0.5},
#  (u'to', u'cables'): {u'component': 0.3333333333333333,
#   u'have': 0.3333333333333333,
#   u'these': 0.3333333333333333},
#  (u'in', u'field'): {u'each': 0.5, u'every': 0.5},
#  (u'used', u'on'): {u'it': 0.6666666666666666, u'this': 0.3333333333333333},
#  (u'my', u'life'): {u'entire': 0.5, u'whole': 0.5},
#  (u'put', u'it'): {u'in': 0.5, u'together': 0.5},
#  (u'day', u'it'): {u',': 0.3333333333333333,
#   u'.': 0.3333333333333333,
#   u'and': 0.3333333333333333},
#  (u'paper', u'my'): {u'after': 0.5, u'by': 0.5},
#  (u'because', u'most'): {u'of': 0.5, u'with': 0.5},
#  (u'now', u'they'): {u')': 0.14285714285714285,
#   u'.': 0.2857142857142857,
#   u'and': 0.2857142857142857,
#   u'since': 0.14285714285714285,
#   u'thinking': 0.14285714285714285},
#  (u'of', u'receivers'): {u'expensive': 0.5, u'your': 0.5},
#  (u'you', u'.'): {u'.': 0.05,
#   u'are': 0.1,
#   u'desire': 0.05,
#   u'expected': 0.05,
#   u'go': 0.1,
#   u'have': 0.1,
#   u'know': 0.05,
#   u'need': 0.15,
#   u'physically': 0.05,
#   u'prefer': 0.05,
#   u'purchase': 0.1,
#   u'want': 0.1,
#   u'wish': 0.05},
#  (u'the', u'review'): {u'5-star': 0.2,
#   u'above': 0.2,
#   u'businessweek': 0.2,
#   u'fifth': 0.2,
#   u'other': 0.2},
#  (u')', u'when'): {u'.': 0.6666666666666666, u'surprised': 0.3333333333333333},
#  (u'to', u'is'): {u'and': 0.05555555555555555,
#   u'another': 0.05555555555555555,
#   u'cds': 0.05555555555555555,
#   u'do': 0.3333333333333333,
#   u'know': 0.05555555555555555,
#   u'me': 0.05555555555555555,
#   u'note': 0.05555555555555555,
#   u'obtain': 0.05555555555555555,
#   u'pc': 0.05555555555555555,
#   u'purchase': 0.05555555555555555,
#   u'recover': 0.05555555555555555,
#   u'them': 0.05555555555555555,
#   u'this': 0.05555555555555555},
#  (u'the', u'goes'): {u'clip': 0.2,
#   u'product': 0.2,
#   u'same': 0.4,
#   u'saying': 0.2},
#  (u'to', u'good'): {u'a': 0.375,
#   u'find': 0.125,
#   u'give': 0.125,
#   u'look': 0.125,
#   u'obtain': 0.125,
#   u'the': 0.125},
#  (u'it', u'impossible'): {u"'s": 0.5, u'is': 0.5},
#  (u'clear', u'with'): {u'and': 0.5, u'it': 0.5},
#  (u'other', u')'): {u'brands': 0.25, u'receivers': 0.25, u'things': 0.5},
#  (u'it', u'well'): {u"'s": 0.10526315789473684,
#   u'.': 0.05263157894736842,
#   u'as': 0.05263157894736842,
#   u'came': 0.05263157894736842,
#   u'is': 0.05263157894736842,
#   u'money': 0.05263157894736842,
#   u'perfectly': 0.05263157894736842,
#   u'performed': 0.05263157894736842,
#   u'prints': 0.05263157894736842,
#   u'protects': 0.05263157894736842,
#   u'very': 0.05263157894736842,
#   u'was': 0.10526315789473684,
#   u'worked': 0.10526315789473684,
#   u'works': 0.15789473684210525},
#  (u'not', u'quality'): {u'bose': 0.3333333333333333,
#   u'cd': 0.3333333333333333,
#   u'great': 0.3333333333333333},
#  (u'some', u'that'): {u'aspects': 0.25,
#   u'features': 0.25,
#   u'observations': 0.25,
#   u'points': 0.25},
#  (u'the', u'broke'): {u'knobs': 0.5, u'plastic': 0.5},
#  (u'them', u'there'): {u'.': 0.2,
#   u'because': 0.2,
#   u'if': 0.2,
#   u'on': 0.2,
#   u'that': 0.2},
#  (u'i', u'into'): {u'plug': 0.5, u'ran': 0.5},
#  (u'their', u'are'): {u'bugs': 0.3333333333333333,
#   u'highs': 0.3333333333333333,
#   u'profits': 0.3333333333333333},
#  (u'looked', u'the'): {u'at': 0.5, u'over': 0.5},
#  (u'look', u'and'): {u'(': 0.2,
#   u'good': 0.2,
#   u'great': 0.2,
#   u'sharp': 0.2,
#   u'stretched': 0.2},
#  (u'to', u'two'): {u'hit': 0.3333333333333333,
#   u'put': 0.3333333333333333,
#   u'reveal': 0.3333333333333333},
#  (u',', u','): {u'30d': 0.004672897196261682,
#   u'ac': 0.004672897196261682,
#   u'accurate': 0.009345794392523364,
#   u'affordable': 0.004672897196261682,
#   u'alas': 0.004672897196261682,
#   u'alone': 0.004672897196261682,
#   u'and': 0.009345794392523364,
#   u'apex': 0.004672897196261682,
#   u'appointments': 0.004672897196261682,
#   u'backward': 0.004672897196261682,
#   u'basically': 0.004672897196261682,
#   u'bass': 0.004672897196261682,
#   u'battery': 0.004672897196261682,
#   u'belts': 0.004672897196261682,
#   u'besides': 0.004672897196261682,
#   u'blessfully': 0.004672897196261682,
#   u'blow-torches': 0.004672897196261682,
#   u'books': 0.004672897196261682,
#   u'bose': 0.004672897196261682,
#   u'brightness': 0.004672897196261682,
#   u'businesses': 0.004672897196261682,
#   u'but': 0.014018691588785047,
#   u'calculator': 0.004672897196261682,
#   u'calender': 0.004672897196261682,
#   u'canada': 0.004672897196261682,
#   u'case': 0.004672897196261682,
#   u'cd-player': 0.004672897196261682,
#   u'cds': 0.004672897196261682,
#   u'classical': 0.004672897196261682,
#   u'cleaner': 0.004672897196261682,
#   u'clips': 0.009345794392523364,
#   u'clocks': 0.004672897196261682,
#   u'confortable': 0.004672897196261682,
#   u'corded': 0.004672897196261682,
#   u'courteous': 0.004672897196261682,
#   u'creative': 0.004672897196261682,
#   u'creatures': 0.004672897196261682,
#   u'crisp': 0.004672897196261682,
#   u'daneelec': 0.004672897196261682,
#   u'dates': 0.004672897196261682,
#   u'dc': 0.009345794392523364,
#   u'depth': 0.004672897196261682,
#   u'desktops': 0.004672897196261682,
#   u'down': 0.004672897196261682,
#   u'dsl': 0.004672897196261682,
#   u'durable': 0.004672897196261682,
#   u'duracell': 0.004672897196261682,
#   u'dvds': 0.004672897196261682,
#   u'e.g.': 0.004672897196261682,
#   u'elevation': 0.004672897196261682,
#   u'end': 0.004672897196261682,
#   u'etc': 0.009345794392523364,
#   u'etc.': 0.02336448598130841,
#   u'europe': 0.004672897196261682,
#   u'faxing': 0.004672897196261682,
#   u'features': 0.004672897196261682,
#   u'flanged': 0.004672897196261682,
#   u'flash': 0.004672897196261682,
#   u'fm': 0.004672897196261682,
#   u'folders': 0.004672897196261682,
#   u'games': 0.004672897196261682,
#   u'garmin': 0.004672897196261682,
#   u'h320': 0.004672897196261682,
#   u'high': 0.004672897196261682,
#   u'hiking': 0.004672897196261682,
#   u'however': 0.04205607476635514,
#   u'hp': 0.004672897196261682,
#   u'including': 0.004672897196261682,
#   u'install': 0.004672897196261682,
#   u'ipod': 0.009345794392523364,
#   u'itunes': 0.004672897196261682,
#   u'jbl': 0.004672897196261682,
#   u'kayaking': 0.004672897196261682,
#   u'keyboards': 0.004672897196261682,
#   u'keys': 0.004672897196261682,
#   u'klipsch': 0.004672897196261682,
#   u'large': 0.004672897196261682,
#   u'leather': 0.004672897196261682,
#   u'lexar': 0.004672897196261682,
#   u'light': 0.004672897196261682,
#   u'lightweight': 0.004672897196261682,
#   u'logitech': 0.004672897196261682,
#   u'lunch': 0.004672897196261682,
#   u'may': 0.004672897196261682,
#   u'me': 0.004672897196261682,
#   u'medialife': 0.004672897196261682,
#   u'middle': 0.004672897196261682,
#   u'nemo': 0.004672897196261682,
#   u'net.exe': 0.004672897196261682,
#   u'non-belkin': 0.004672897196261682,
#   u'notes': 0.004672897196261682,
#   u'options': 0.009345794392523364,
#   u'painter': 0.004672897196261682,
#   u'pan': 0.004672897196261682,
#   u'panasonic': 0.004672897196261682,
#   u'paper': 0.004672897196261682,
#   u'pc': 0.004672897196261682,
#   u'pda': 0.004672897196261682,
#   u'pens': 0.004672897196261682,
#   u'photo': 0.009345794392523364,
#   u'photos': 0.004672897196261682,
#   u'photoshop': 0.004672897196261682,
#   u'playing': 0.004672897196261682,
#   u'pop': 0.004672897196261682,
#   u'popping': 0.004672897196261682,
#   u'price': 0.004672897196261682,
#   u'pricey': 0.004672897196261682,
#   u'ps2': 0.009345794392523364,
#   u'ram': 0.004672897196261682,
#   u'really': 0.009345794392523364,
#   u'realplayer': 0.004672897196261682,
#   u'recorder': 0.004672897196261682,
#   u'reliable': 0.009345794392523364,
#   u'remote': 0.004672897196261682,
#   u'reorder': 0.004672897196261682,
#   u'resolutions': 0.004672897196261682,
#   u'response': 0.004672897196261682,
#   u'restaurants': 0.004672897196261682,
#   u'rhapsody': 0.004672897196261682,
#   u'rich': 0.004672897196261682,
#   u'rock': 0.004672897196261682,
#   u'router': 0.004672897196261682,
#   u's-video': 0.004672897196261682,
#   u'sanyo': 0.004672897196261682,
#   u'say': 0.009345794392523364,
#   u'scanning': 0.004672897196261682,
#   u'sd': 0.004672897196261682,
#   u'search': 0.004672897196261682,
#   u'silver': 0.004672897196261682,
#   u'siren': 0.004672897196261682,
#   u'sleek': 0.004672897196261682,
#   u'slim': 0.004672897196261682,
#   u'small': 0.014018691588785047,
#   u'smooth': 0.009345794392523364,
#   u'smoothness': 0.004672897196261682,
#   u'snatch': 0.004672897196261682,
#   u'sony': 0.004672897196261682,
#   u'soothing': 0.004672897196261682,
#   u'sound': 0.004672897196261682,
#   u'squeeze': 0.004672897196261682,
#   u'static': 0.004672897196261682,
#   u'stylish': 0.009345794392523364,
#   u'sub-dividers': 0.004672897196261682,
#   u'subways': 0.004672897196261682,
#   u't5400': 0.004672897196261682,
#   u't5420': 0.004672897196261682,
#   u't5600': 0.004672897196261682,
#   u't5620': 0.004672897196261682,
#   u't5700': 0.004672897196261682,
#   u't5720': 0.004672897196261682,
#   u't5800': 0.004672897196261682,
#   u'tasks': 0.004672897196261682,
#   u'taut': 0.004672897196261682,
#   u'techno/electronic': 0.004672897196261682,
#   u'teleconverters': 0.004672897196261682,
#   u'testbooks': 0.004672897196261682,
#   u'though': 0.028037383177570093,
#   u'tilt': 0.004672897196261682,
#   u'tv': 0.014018691588785047,
#   u'vests': 0.004672897196261682,
#   u'video': 0.009345794392523364,
#   u'vinyl': 0.004672897196261682,
#   u'voice': 0.004672897196261682,
#   u'volume': 0.004672897196261682,
#   u'warm': 0.009345794392523364,
#   u'waypoints': 0.004672897196261682,
#   u'weight': 0.004672897196261682,
#   u'well': 0.004672897196261682,
# ...
#   u'off': 0.01680672268907563,
#   u'on': 0.03361344537815126,
#   u'raises': 0.008403361344537815,
#   u'receives': 0.008403361344537815,
#   u'said': 0.008403361344537815,
#   u'says': 0.008403361344537815,
#   u'shipped': 0.008403361344537815,
#   u'since': 0.008403361344537815,
#   u'solved': 0.008403361344537815,
#   u'taps': 0.008403361344537815,
#   u'thru': 0.008403361344537815,
#   u'to': 0.03361344537815126,
#   u'up': 0.008403361344537815,
#   u'was': 0.03361344537815126,
#   u'while': 0.008403361344537815,
#   u'with': 0.008403361344537815,
#   u'worked': 0.008403361344537815,
#   u'worth': 0.01680672268907563},
#  (u'is', u'the'): {u',': 0.0136986301369863,
#   u'.': 0.0273972602739726,
#   u'about': 0.0273972602739726,
#   u'all': 0.0136986301369863,
#   u'among': 0.0273972602739726,
#   u'answer': 0.0136986301369863,
#   u'at': 0.0136986301369863,
#   u'basically': 0.0136986301369863,
#   u'between': 0.0136986301369863,
#   u'beyond': 0.0136986301369863,
#   u'called': 0.0136986301369863,
#   u'definately': 0.0136986301369863,
#   u'enable': 0.0136986301369863,
#   u'for': 0.0136986301369863,
#   u'in': 0.0821917808219178,
#   u"n't": 0.0273972602739726,
#   u'nearly': 0.0136986301369863,
#   u'not': 0.0273972602739726,
#   u'of': 0.0136986301369863,
#   u'ok.': 0.0136986301369863,
#   u'on': 0.0547945205479452,
#   u'open': 0.0136986301369863,
#   u'poor.on': 0.0136986301369863,
#   u'probably': 0.0273972602739726,
#   u'really': 0.0136986301369863,
#   u'reload': 0.0136986301369863,
#   u'selling': 0.0136986301369863,
#   u'simply': 0.0136986301369863,
#   u'that': 0.3013698630136986,
#   u'triple': 0.0136986301369863,
#   u'under': 0.0136986301369863,
#   u'with': 0.0273972602739726,
#   u'worth': 0.0684931506849315},
#  (u'using', u'product'): {u'the': 0.5, u'this': 0.5},
#  (u'ipod', u'and'): {u',': 0.5714285714285714,
#   u'-': 0.14285714285714285,
#   u'holder': 0.14285714285714285,
#   u'slot': 0.14285714285714285},
#  (u',', u'bought'): {u'and': 0.125, u'i': 0.875},
#  (u'together', u'that'): {u'.': 0.5, u'so': 0.5},
#  (u'cool', u'i'): {u'.': 0.6666666666666666, u'but': 0.3333333333333333},
#  (u'these', u'there'): {u'are': 0.5, u'movies': 0.5},
#  (u'works', u'the'): {u'off': 0.25, u'on': 0.25, u'with': 0.5},
#  (u'case', u'no'): {u',': 0.5, u'.': 0.5},
#  (u'level', u'i'): {u',': 0.3333333333333333, u'.': 0.6666666666666666},
#  (u'all', u','): {u'about': 0.16666666666666666,
#   u'modes': 0.16666666666666666,
#   u'seriousness': 0.3333333333333333,
#   u'three': 0.16666666666666666,
#   u'told': 0.16666666666666666},
#  (u'on', u'of'): {u'.': 0.06666666666666667,
#   u'all': 0.13333333333333333,
#   u'both': 0.06666666666666667,
#   u'each': 0.06666666666666667,
#   u'one': 0.13333333333333333,
#   u'scraps': 0.06666666666666667,
#   u'severity': 0.06666666666666667,
#   u'some': 0.06666666666666667,
#   u'top': 0.2,
#   u'tops': 0.06666666666666667,
#   u'type': 0.06666666666666667},
#  (u'sitting', u'to'): {u'close': 0.3333333333333333,
#   u'next': 0.6666666666666666},
#  (u'i', u'like'): {u"'d": 0.06451612903225806,
#   u'actually': 0.03225806451612903,
#   u'also': 0.16129032258064516,
#   u'do': 0.03225806451612903,
#   u'especially': 0.03225806451612903,
#   u'feel': 0.03225806451612903,
#   u'felt': 0.06451612903225806,
#   u'really': 0.22580645161290322,
#   u'sound': 0.03225806451612903,
#   u'still': 0.06451612903225806,
#   u'would': 0.25806451612903225},
#  (u'a', u'complaint'): {u'minor': 0.3333333333333333,
#   u'single': 0.6666666666666666},
#  (u'no', u'at'): {u'brainer': 0.07692307692307693,
#   u'distortion': 0.15384615384615385,
#   u'fun': 0.07692307692307693,
#   u'interference': 0.07692307692307693,
#   u'problem': 0.15384615384615385,
#   u'problems': 0.15384615384615385,
#   u'screen': 0.07692307692307693,
#   u'time': 0.15384615384615385,
#   u'trouble': 0.07692307692307693},
#  (u'speakers', u'as'): {u',': 0.5, u'.': 0.25, u'perform': 0.25},
#  (u'company', u'that'): {u"'s": 0.5, u'for': 0.5},
#  (u'picture', u'as'): {u'quality': 0.6666666666666666,
#   u'was': 0.3333333333333333},
#  (u'a', u'cable'): {u'belkin': 0.07142857142857142,
#   u'cheap': 0.07142857142857142,
#   u'connector': 0.07142857142857142,
#   u'crossover': 0.07142857142857142,
#   u'dvi': 0.14285714285714285,
#   u'dvi-d': 0.14285714285714285,
#   u'dvid': 0.07142857142857142,
#   u'good': 0.07142857142857142,
#   u'hdmi': 0.07142857142857142,
#   u'monster': 0.07142857142857142,
#   u'retractable': 0.07142857142857142,
#   u'usb': 0.07142857142857142},
#  (u'a', u'since'): {u'blessing': 0.2,
#   u'bonus': 0.2,
#   u'problem': 0.2,
#   u'while': 0.4},
#  (u'--', u'these'): {u'-': 0.5, u'placing': 0.5},
#  (u'seal', u'you'): {u'.': 0.5, u'as': 0.5},
#  (u'my', u'box'): {u'cable': 0.6666666666666666,
#   u'directv': 0.3333333333333333},
#  (u'(', u'i'): {u'and': 0.1875,
#   u'but': 0.0625,
#   u'so': 0.0625,
#   u'springs': 0.0625,
#   u'subjective': 0.0625,
#   u'that': 0.125,
#   u'though': 0.0625,
#   u'which': 0.25,
#   u'yes': 0.0625,
#   u'yet': 0.0625},
#  (u'had', u'this'): {u'bought': 0.5, u'purchased': 0.25, u'with': 0.25},
#  (u'always', u'it'): {u'buy': 0.5, u'unlocked': 0.5},
#  (u'as', u'it'): {u'printing': 0.5, u'when': 0.5},
#  (u'that', u'the'): {u"'s": 0.027777777777777776,
#   u',': 0.027777777777777776,
#   u'.': 0.027777777777777776,
#   u'among': 0.027777777777777776,
#   u'at': 0.027777777777777776,
#   u'but': 0.027777777777777776,
#   u'covers': 0.08333333333333333,
#   u'fills': 0.027777777777777776,
#   u'for': 0.05555555555555555,
#   u'had': 0.027777777777777776,
#   u'has': 0.027777777777777776,
#   u'having': 0.027777777777777776,
#   u'is': 0.1388888888888889,
#   u'keeps': 0.027777777777777776,
#   u'last': 0.027777777777777776,
#   u'of': 0.027777777777777776,
#   u'on': 0.027777777777777776,
#   u'plugging': 0.027777777777777776,
#   u'protects': 0.027777777777777776,
#   u'say': 0.027777777777777776,
#   u'sends/recieves': 0.027777777777777776,
#   u'simplifies': 0.027777777777777776,
#   u'snaps': 0.027777777777777776,
#   u'sometimes': 0.027777777777777776,
#   u'touch': 0.027777777777777776,
#   u'using': 0.027777777777777776,
#   u'was': 0.027777777777777776,
#   u'were': 0.027777777777777776,
#   u'when': 0.027777777777777776},
#  (u'i', u'experience'): {u'have': 0.5, u'know': 0.5},
#  (u'is', u'incredible'): {u'absolutely': 0.3333333333333333,
#   u'an': 0.6666666666666666},
#  (u'had', u'trouble'): {u'no': 0.6, u'some': 0.4},
#  (u'can', u'what'): {u'alter': 0.5, u'compensate': 0.5},
#  (u'computer', u'like'): {u'accessories': 0.5, u'acts': 0.5},
#  (u'he', u'it'): {u'loves': 0.6666666666666666, u'said': 0.3333333333333333},
#  (u'can', u'over'): {u'make': 0.3333333333333333,
#   u'store': 0.3333333333333333,
#   u'transmit': 0.3333333333333333},
#  (u'music', u'these'): {u'on': 0.5, u'through': 0.5},
#  (u'products', u'have'): {u'reviews': 0.5, u'that': 0.5},
#  (u'photos', u'i'): {u'.': 0.5, u'when': 0.5},
#  (u'it', u'what'): {u"'s": 0.25, u'does': 0.5, u'makes': 0.25},
#  (u'thanks', u'!'): {u'amazon': 0.5, u'hp': 0.5},
#  (u'customer', u','): {u'care': 0.5, u'service': 0.5},
#  (u'room', u'it'): {u',': 0.8333333333333334, u'and': 0.16666666666666666},
#  (u'i', u'buying'): {u"'m": 0.5, u'keep': 0.25, u'was': 0.25},
#  (u'of', u'cameras'): {u'finepix': 0.5, u'my': 0.5},
#  (u'you', u'also'): {u'can': 0.8571428571428571, u'may': 0.14285714285714285},
#  (u'this', u'for'): {u',': 0.023255813953488372,
#   u'backpack': 0.023255813953488372,
#   u'cable': 0.023255813953488372,
#   u'camera': 0.023255813953488372,
#   u'card': 0.06976744186046512,
#   u'controller': 0.023255813953488372,
#   u'drive': 0.023255813953488372,
#   u'headphone': 0.023255813953488372,
#   u'headset': 0.023255813953488372,
#   u'is': 0.046511627906976744,
#   u'item': 0.046511627906976744,
#   u'iterm': 0.023255813953488372,
#   u'keyboard': 0.023255813953488372,
#   u'model': 0.023255813953488372,
#   u'monitor': 0.023255813953488372,
#   u'mouse': 0.023255813953488372,
#   u'one': 0.09302325581395349,
#   u'online': 0.023255813953488372,
#   u'out': 0.023255813953488372,
#   u'perfect': 0.023255813953488372,
#   u'phone': 0.023255813953488372,
#   u'player/recorder': 0.023255813953488372,
#   u'printer': 0.023255813953488372,
#   u'product': 0.09302325581395349,
#   u'quality': 0.023255813953488372,
#   u'question': 0.023255813953488372,
#   u'receiver': 0.023255813953488372,
#   u'request': 0.023255813953488372,
#   u'router': 0.023255813953488372,
#   u'tv': 0.046511627906976744,
#   u'up': 0.023255813953488372,
#   u'was': 0.023255813953488372},
#  (u',', u'ceilings'): {u'high': 0.5, u'low': 0.5},
#  (u'would', u'.'): {u'be': 0.2,
#   u'expect': 0.2,
#   u'happen': 0.2,
#   u'look': 0.2,
#   u'wish': 0.2},
#  (u'one', u'when'): {u'.': 0.5, u'then': 0.5},
#  (u'consider', u'a'): {u'having': 0.3333333333333333,
#   u'it': 0.6666666666666666},
#  (u'point', u'the'): {u',': 0.25, u'.': 0.25, u'by': 0.25, u'to': 0.25},
#  (u'nearly', u'in'): {u'cried': 0.5, u'instantly': 0.5},
#  (u'a', u'while'): {u'good': 0.5, u'map': 0.5},
#  (u'or', u'some'): {u'do': 0.5, u'what': 0.5},
#  (u'like', u'who'): {u'me': 0.6666666666666666,
#   u'someone': 0.3333333333333333},
#  (u'one', u'of'): {u'because': 0.2,
#   u'direction': 0.1,
#   u'end': 0.1,
#   u'heck': 0.1,
#   u'hour': 0.2,
#   u'side': 0.1,
#   u'tape': 0.1,
#   u'word': 0.1},
#  (u'that', u'this'): {u',': 0.2222222222222222,
#   u'.': 0.2222222222222222,
#   u'allows': 0.1111111111111111,
#   u'are': 0.1111111111111111,
#   u'enable': 0.1111111111111111,
#   u'even': 0.1111111111111111,
#   u'makes': 0.1111111111111111},
#  (u'v200', u'it'): {u',': 0.5, u'.': 0.5},
#  (u'was', u'too'): {u'just': 0.5, u'only': 0.5},
#  (u'something', u'the'): {u'.': 0.5, u'that': 0.5},
#  (u'and', u'worked'): {u'both': 0.08333333333333333,
#   u'fm': 0.08333333333333333,
#   u'has': 0.25,
#   u'it': 0.5833333333333334},
#  (u'base', u'the'): {u'.': 0.3333333333333333,
#   u'and': 0.3333333333333333,
#   u'of': 0.3333333333333333},
#  (u'the', u'with'): {u'album': 0.024390243902439025,
#   u'backpack': 0.024390243902439025,
#   u'car': 0.024390243902439025,
#   u'controls': 0.024390243902439025,
#   u'date/time': 0.024390243902439025,
#   u'dice': 0.024390243902439025,
#   u'earphone': 0.024390243902439025,
#   u'ease': 0.04878048780487805,
#   u'gps': 0.04878048780487805,
#   u'grave': 0.024390243902439025,
#   u'instructions': 0.024390243902439025,
#   u'junction': 0.024390243902439025,
#   u'lens': 0.024390243902439025,
#   u'menu': 0.024390243902439025,
#   u'mouse': 0.04878048780487805,
#   u'one': 0.024390243902439025,
#   u'ones': 0.024390243902439025,
#   u'phone': 0.07317073170731707,
#   u'picture': 0.04878048780487805,
#   u'pip': 0.024390243902439025,
#   u'problem': 0.07317073170731707,
#   u'same': 0.024390243902439025,
#   u'speakers': 0.04878048780487805,
#   u'station': 0.024390243902439025,
#   u'telephone': 0.04878048780487805,
#   u'tweaking': 0.024390243902439025,
#   u'unit': 0.024390243902439025,
#   u'uplink': 0.024390243902439025,
#   u'way': 0.024390243902439025,
#   u'window': 0.024390243902439025,
#   u'ysp-1': 0.024390243902439025},
#  (u'but', u'you'): {u'as': 0.05263157894736842,
#   u'if': 0.5263157894736842,
#   u'once': 0.21052631578947367,
#   u'unless': 0.05263157894736842,
#   u'when': 0.15789473684210525},
#  (u'a', u'portable'): {u'budget': 0.5, u'small': 0.5},
#  (u'fast', u'.'): {u'delivery': 0.25,
#   u'enough': 0.25,
#   u'shipping': 0.25,
#   u'transfer': 0.25},
#  (u"'s", u'great'): {u'a': 0.75,
#   u'another': 0.08333333333333333,
#   u'look': 0.08333333333333333,
#   u'sound': 0.08333333333333333},
#  (u'to', u'ear'): {u'my': 0.5, u'the': 0.5},
#  (u'color', u'the'): {u'.': 0.6666666666666666, u'and': 0.3333333333333333},
#  (u'need', u'use'): {u'or': 0.2, u'to': 0.8},
#  (u'thing', u'i'): {u'!': 0.25, u'that': 0.5, u'until': 0.25},
#  (u'can', u'an'): {u'be': 0.16666666666666666,
#   u'get': 0.3333333333333333,
#   u'give': 0.16666666666666666,
#   u'hold': 0.16666666666666666,
#   u'record': 0.16666666666666666},
#  (u'for', u'is'): {u'ipod': 0.5, u'me': 0.5},
#  (u'one', u'me'): {u'for': 0.75, u'with': 0.25},
#  (u'a', u'window'): {u'glass': 0.5, u'small': 0.5},
#  (u'do', u'this'): {u'recommend': 0.5, u'run': 0.5},
#  (u'a', u'button'): {u'hold': 0.3333333333333333,
#   u'one': 0.3333333333333333,
#   u'two': 0.3333333333333333},
#  (u'is', u'in'): {u',': 0.05263157894736842,
#   u'better': 0.05263157894736842,
#   u'clipped': 0.05263157894736842,
#   u'good': 0.15789473684210525,
#   u'great': 0.05263157894736842,
#   u'lacking': 0.05263157894736842,
#   u'literally': 0.05263157894736842,
#   u'locked': 0.05263157894736842,
#   u'nice': 0.05263157894736842,
#   u'only': 0.10526315789473684,
#   u'overpriced': 0.05263157894736842,
#   u'placed': 0.05263157894736842,
#   u'tops': 0.05263157894736842,
#   u'typical': 0.10526315789473684,
#   u'written': 0.05263157894736842},
#  (u'jack', u'it'): {u'.': 0.6666666666666666, u'and': 0.3333333333333333},
#  (u'of', u'five'): {u'its': 0.5, u'these': 0.5},
#  (u'still', u'.'): {u'there': 0.16666666666666666,
#   u'true': 0.16666666666666666,
#   u'vibrant': 0.16666666666666666,
#   u'visable': 0.16666666666666666,
#   u'working': 0.16666666666666666,
#   u'works': 0.16666666666666666},
#  (u'had', u'problems'): {u'any': 0.3225806451612903,
#   u'no': 0.6129032258064516,
#   u'not': 0.03225806451612903,
#   u'perfomace': 0.03225806451612903},
#  (u'that', u"'s"): {u'it': 0.8888888888888888, u'job': 0.1111111111111111},
#  (u'the', u'usb'): {u'cheapest': 0.3333333333333333,
#   u'computer': 0.3333333333333333,
#   u'typical': 0.3333333333333333},
#  (u'.', u'.'): {u')': 0.08333333333333333,
#   u'affordable': 0.08333333333333333,
#   u'comfort': 0.08333333333333333,
#   u'compatibility': 0.08333333333333333,
#   u'e.g': 0.08333333333333333,
#   u'fanstastic': 0.08333333333333333,
#   u'features': 0.08333333333333333,
#   u'n.e.w': 0.08333333333333333,
#   u'overview': 0.08333333333333333,
#   u'recommended': 0.08333333333333333,
#   u'sound': 0.08333333333333333,
#   u'wow': 0.08333333333333333},
#  (u'it', u'under'): {u'is': 0.5, u'yet': 0.5},
#  (u',', u'great'): {u'@': 0.14285714285714285,
#   u'a': 0.2857142857142857,
#   u'and': 0.2857142857142857,
#   u'just': 0.14285714285714285,
#   u'play': 0.14285714285714285},
#  (u'product', u'was'): {u'description': 0.25, u'i': 0.75},
#  (u'much', u'than'): {u'better': 0.4482758620689655,
#   u'cheaper': 0.06896551724137931,
#   u'faster': 0.034482758620689655,
#   u'heavier': 0.034482758620689655,
#   u'higher': 0.034482758620689655,
#   u'less': 0.034482758620689655,
#   u'lighter': 0.034482758620689655,
#   u'lower': 0.10344827586206896,
#   u'more': 0.06896551724137931,
#   u'smaller': 0.06896551724137931,
#   u'stronger': 0.034482758620689655,
#   u'worse': 0.034482758620689655},
#  (u'outlook', u','): {u'before': 0.5, u'messages': 0.5},
#  (u'will', u'sound'): {u'not': 0.5, u'probably': 0.5},
#  (u'camera', u'some'): {u'had': 0.5, u'with': 0.5},
#  (u'i', u'how'): {u'like': 0.5,
#   u'miscalculated': 0.16666666666666666,
#   u'wonder': 0.3333333333333333},
#  (u'market', u'as'): {u'it': 0.5, u'looks': 0.5},
#  (u'quality', u'for'): {u'...': 0.3333333333333333,
#   u'company': 0.3333333333333333,
#   u'scanner': 0.3333333333333333},
#  (u'stars', u'it'): {u'.': 0.3333333333333333,
#   u'because': 0.3333333333333333,
#   u'if': 0.3333333333333333},
#  (u'i', u'had'): {u"'ve": 0.4166666666666667,
#   u'actually': 0.011904761904761904,
#   u'already': 0.011904761904761904,
#   u'even': 0.011904761904761904,
#   u'ever': 0.03571428571428571,
#   u'have': 0.35714285714285715,
#   u'initially': 0.011904761904761904,
#   u'just': 0.023809523809523808,
#   u'never': 0.023809523809523808,
#   u'previously': 0.03571428571428571,
#   u'simply': 0.023809523809523808,
#   u'still': 0.023809523809523808,
#   u'unfortunately': 0.011904761904761904},
#  (u'i', u'received'): {u'first': 0.25,
#   u'had': 0.25,
#   u'never': 0.25,
#   u'recently': 0.25},
#  (u'.', u'company'): {u'good': 0.5, u'the': 0.5},
#  (u',', u'with'): {u'along': 0.09090909090909091,
#   u'and': 0.09090909090909091,
#   u'as': 0.030303030303030304,
#   u'because': 0.030303030303030304,
#   u'both': 0.030303030303030304,
#   u'burned': 0.030303030303030304,
#   u'but': 0.2727272727272727,
#   u'especially': 0.06060606060606061,
#   u'even': 0.15151515151515152,
#   u'interfaces': 0.030303030303030304,
#   u'now': 0.030303030303030304,
#   u'sleek': 0.030303030303030304,
#   u'so': 0.030303030303030304,
#   u'sync': 0.030303030303030304,
#   u'then': 0.030303030303030304,
#   u'working': 0.030303030303030304},
#  (u'very', u';'): {u'good': 0.5, u'portable': 0.5},
#  ...}
